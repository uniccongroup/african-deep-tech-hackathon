# %%
# !nvidia-smi
# Out:
# Thu Jul 17 08:35:28 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/hackathon
# Out:
# /content/drive/MyDrive/hackathon

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("iarunava/cell-images-for-detecting-malaria")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/cell-images-for-detecting-malaria

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt



parasitized_dir = os.path.join(path, "cell_images", "Parasitized")

image_files = os.listdir(parasitized_dir)

image_files = [f for f in image_files if f.endswith(('.png', '.jpg', '.jpeg'))]

sample_image_path = os.path.join(parasitized_dir, image_files[0])


image = Image.open(sample_image_path)

plt.imshow(image)
plt.title("Parasitized Cell Example")
plt.axis("off")
plt.show()

# %%
# !pip install ultralytics
# !pip install torch torchvision torchaudio
# !pip install opencv-python
# !pip install matplotlib
# !pip install scikit-learn
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.167-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.7.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.167-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.167 ultralytics-thop-2.0.14
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)

# %%
import os
import shutil
from pathlib import Path
import random
from ultralytics import YOLO
import torch
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os
import shutil
import random
from pathlib import Path

def create_dataset_split(source_dir, output_dir, train_ratio=0.7, val_ratio=0.2, test_ratio=0.1):
    """
    Split dataset into train/val/test for YOLOv8 classification
    """
    splits = ['train', 'val', 'test']
    classes = ['Parasitized', 'Uninfected']

    for split in splits:
        for cls in classes:
            os.makedirs(os.path.join(output_dir, split, cls), exist_ok=True)
    for cls in classes:
        class_dir = os.path.join(source_dir, cls)
        images = [f for f in os.listdir(class_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
        random.shuffle(images)
        total = len(images)
        train_end = int(total * train_ratio)
        val_end = int(total * (train_ratio + val_ratio))

        train_images = images[:train_end]
        val_images = images[train_end:val_end]
        test_images = images[val_end:]

        for img in train_images:
            shutil.copy2(os.path.join(class_dir, img), os.path.join(output_dir, 'train', cls, img))

        for img in val_images:
            shutil.copy2(os.path.join(class_dir, img), os.path.join(output_dir, 'val', cls, img))

        for img in test_images:
            shutil.copy2(os.path.join(class_dir, img), os.path.join(output_dir, 'test', cls, img))

        print(f"{cls}: {len(train_images)} train, {len(val_images)} val, {len(test_images)} test")

source_directory = f"{path}/cell_images"
output_directory = "malaria_dataset"
create_dataset_split(source_directory, output_directory)
# Out:
# Parasitized: 9645 train, 2756 val, 1378 test
# Uninfected: 9645 train, 2756 val, 1378 test

# %%
# from ultralytics import YOLO
# import torch

# def train_malaria_classifier():
#     """
#     Train YOLOv8 classification model for malaria detection
#     """

#     # Check if GPU is available
#     device = 'cuda' if torch.cuda.is_available() else 'cpu'
#     print(f"Using device: {device}")

#     # Load YOLOv8 classification model
#     model = YOLO('yolov8n-cls.pt')  # nano model for faster training
#     # Alternative models: yolov8s-cls.pt, yolov8m-cls.pt, yolov8l-cls.pt, yolov8x-cls.pt

#     # Training parameters
#     results = model.train(
#         data='malaria_dataset',
#         epochs=100,
#         imgsz=224,
#         batch=16,
#         device=device,
#         workers=4,
#         patience=10,
#         save=True,
#         save_period=10,
#         val=True,
#         plots=True,
#         verbose=True,
#         seed=42,

#         # Data augmentation parameters
#         hsv_h=0.015,           # HSV-Hue augmentation
#         hsv_s=0.7,             # HSV-Saturation augmentation
#         hsv_v=0.4,             # HSV-Value augmentation
#         degrees=0.0,           # rotation degrees
#         translate=0.1,         # translation
#         scale=0.5,             # scale
#         shear=0.0,             # shear
#         perspective=0.0,       # perspective
#         flipud=0.0,            # flip up-down
#         fliplr=0.5,            # flip left-right
#         mosaic=0.0,            # mosaic augmentation (not typically used for classification)
#         mixup=0.0,             # mixup augmentation
#         copy_paste=0.0,        # copy-paste augmentation

#         # Optimization parameters
#         optimizer='AdamW',      # optimizer (SGD, Adam, AdamW)
#         lr0=0.001,             # initial learning rate
#         lrf=0.1,               # final learning rate factor
#         momentum=0.937,        # momentum
#         weight_decay=0.0005,   # weight decay
#         warmup_epochs=3,       # warmup epochs
#         warmup_momentum=0.8,   # warmup momentum
#         warmup_bias_lr=0.1,    # warmup bias learning rate

#         # Model parameters
#         dropout=0.0,           # dropout rate

#         # Project organization
#         project='malaria_classification',  # project name
#         name='yolov8_malaria',            # experiment name
#     )

#     return model, results

# # Train the model
# model, results = train_malaria_classifier()

# %% [markdown]
# ### Simple trainig

# %%
from ultralytics import YOLO
import torch

def train_malaria_classifier():
    """
    Train YOLOv8 classification model for malaria detection
    """

    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Using device: {device}")
    model = YOLO('yolov8n-cls.pt')

    results = model.train(
    data='/content/drive/MyDrive/hackathon/datasets',
    epochs=100,
    imgsz=224,
    batch=16,
    device=device,
    workers=4,
    patience=10,
    save=True,
    save_period=10,
    val=True,
    plots=True,
    )

    return model, results

model, results = train_malaria_classifier()
# Out:
# Using device: cuda
# Ultralytics 8.3.167 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/hackathon/datasets, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/classify/train4, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# train: /content/drive/MyDrive/hackathon/datasets/train... found 19290 images in 2 classes ✅
# val: /content/drive/MyDrive/hackathon/datasets/val... found 5512 images in 2 classes ✅
# test: /content/drive/MyDrive/hackathon/datasets/test... found 2756 images in 2 classes ✅
# Overriding model.yaml nc=1000 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    332802  ultralytics.nn.modules.head.Classify         [256, 2]
# YOLOv8n-cls summary: 56 layers, 1,440,850 parameters, 1,440,850 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.4±0.1 ms, read: 7.7±4.6 MB/s, size: 12.1 KB)
# train: Scanning /content/drive/MyDrive/hackathon/datasets/train... 19290 images, 0 corrupt: 100%|██████████| 19290/19290 [00:00<?, ?it/s]
# val: Fast image access ✅ (ping: 4.1±6.8 ms, read: 3.1±1.4 MB/s, size: 12.8 KB)
# val: Scanning /content/drive/MyDrive/hackathon/datasets/val... 5512 images, 0 corrupt: 100%|██████████| 5512/5512 [00:00<?, ?it/s]
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 2 dataloader workers
# Logging results to runs/classify/train4
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100     0.277G     0.3759         10        224: 100%|██████████| 1206/1206 [03:37<00:00,  5.54it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:35<00:00,  4.89it/s]
#                    all      0.947          1
#       Epoch    GPU_mem       loss  Instances       Size
#       2/100     0.281G     0.2932         10        224: 100%|██████████| 1206/1206 [03:13<00:00,  6.23it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:34<00:00,  5.02it/s]
#                    all      0.927          1
#       Epoch    GPU_mem       loss  Instances       Size
#       3/100     0.281G     0.3147         10        224: 100%|██████████| 1206/1206 [03:12<00:00,  6.26it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:35<00:00,  4.88it/s]
#                    all      0.931          1
#       Epoch    GPU_mem       loss  Instances       Size
#       4/100     0.281G      0.298         10        224: 100%|██████████| 1206/1206 [03:11<00:00,  6.28it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:35<00:00,  4.87it/s]
#                    all      0.956          1
#       Epoch    GPU_mem       loss  Instances       Size
#       5/100     0.281G     0.2557         10        224: 100%|██████████| 1206/1206 [03:12<00:00,  6.25it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:36<00:00,  4.75it/s]
#                    all      0.956          1
#       Epoch    GPU_mem       loss  Instances       Size
#       6/100     0.281G     0.2396         10        224: 100%|██████████| 1206/1206 [03:11<00:00,  6.30it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [01:18<00:00,  2.22it/s]
#                    all      0.959          1
#       Epoch    GPU_mem       loss  Instances       Size
#       7/100     0.285G     0.2337         10        224: 100%|██████████| 1206/1206 [03:10<00:00,  6.32it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:35<00:00,  4.82it/s]
#                    all      0.957          1
#       Epoch    GPU_mem       loss  Instances       Size
#       8/100     0.285G     0.2301         10        224: 100%|██████████| 1206/1206 [03:11<00:00,  6.31it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:35<00:00,  4.92it/s]
#                    all      0.957          1
#       Epoch    GPU_mem       loss  Instances       Size
#       9/100     0.285G     0.2261         10        224: 100%|██████████| 1206/1206 [03:09<00:00,  6.36it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:34<00:00,  5.00it/s]
#                    all      0.957          1
#       Epoch    GPU_mem       loss  Instances       Size
#      10/100     0.287G      0.208         10        224: 100%|██████████| 1206/1206 [03:12<00:00,  6.27it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:35<00:00,  4.92it/s]
#                    all      0.963          1
#       Epoch    GPU_mem       loss  Instances       Size
#      11/100     0.291G     0.2111         10        224: 100%|██████████| 1206/1206 [03:11<00:00,  6.30it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:34<00:00,  4.95it/s]
#                    all      0.962          1
#       Epoch    GPU_mem       loss  Instances       Size
#      12/100     0.291G     0.2019         10        224: 100%|██████████| 1206/1206 [03:10<00:00,  6.32it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:34<00:00,  5.02it/s]
#                    all       0.96          1
#       Epoch    GPU_mem       loss  Instances       Size
#      13/100     0.291G     0.2073         10        224: 100%|██████████| 1206/1206 [03:13<00:00,  6.24it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:35<00:00,  4.92it/s]
#                    all      0.962          1
#       Epoch    GPU_mem       loss  Instances       Size
#      14/100     0.291G     0.2028         10        224: 100%|██████████| 1206/1206 [03:11<00:00,  6.31it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:35<00:00,  4.92it/s]
#                    all      0.962          1
#       Epoch    GPU_mem       loss  Instances       Size
#      15/100     0.291G     0.1971         10        224: 100%|██████████| 1206/1206 [03:11<00:00,  6.30it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:35<00:00,  4.91it/s]
#                    all      0.963          1
#       Epoch    GPU_mem       loss  Instances       Size
#      16/100     0.291G     0.2007         10        224: 100%|██████████| 1206/1206 [03:12<00:00,  6.27it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:35<00:00,  4.93it/s]
#                    all      0.968          1
#       Epoch    GPU_mem       loss  Instances       Size
#      17/100     0.291G     0.1977         10        224: 100%|██████████| 1206/1206 [03:04<00:00,  6.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:33<00:00,  5.18it/s]
#                    all      0.967          1
#       Epoch    GPU_mem       loss  Instances       Size
#      18/100     0.291G     0.1923         10        224: 100%|██████████| 1206/1206 [03:07<00:00,  6.44it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:34<00:00,  5.08it/s]
#                    all      0.964          1
#       Epoch    GPU_mem       loss  Instances       Size
#      19/100     0.291G     0.1906         10        224: 100%|██████████| 1206/1206 [03:09<00:00,  6.38it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:36<00:00,  4.74it/s]
#                    all      0.965          1
#       Epoch    GPU_mem       loss  Instances       Size
#      20/100     0.291G     0.1887         10        224: 100%|██████████| 1206/1206 [03:06<00:00,  6.48it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:38<00:00,  4.53it/s]
#                    all      0.968          1
#       Epoch    GPU_mem       loss  Instances       Size
#      21/100     0.291G     0.1932         10        224: 100%|██████████| 1206/1206 [03:12<00:00,  6.27it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:34<00:00,  4.98it/s]
#                    all      0.967          1
#       Epoch    GPU_mem       loss  Instances       Size
#      22/100     0.291G     0.1908         10        224: 100%|██████████| 1206/1206 [03:05<00:00,  6.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:35<00:00,  4.94it/s]
#                    all       0.97          1
#       Epoch    GPU_mem       loss  Instances       Size
#      23/100     0.291G     0.1889         10        224: 100%|██████████| 1206/1206 [03:04<00:00,  6.55it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:35<00:00,  4.93it/s]
#                    all      0.967          1
#       Epoch    GPU_mem       loss  Instances       Size
#      24/100     0.291G     0.1883         10        224: 100%|██████████| 1206/1206 [03:05<00:00,  6.51it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:33<00:00,  5.17it/s]
#                    all      0.968          1
#       Epoch    GPU_mem       loss  Instances       Size
#      25/100     0.291G     0.1816         10        224: 100%|██████████| 1206/1206 [03:08<00:00,  6.39it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:35<00:00,  4.94it/s]
#                    all      0.967          1
#       Epoch    GPU_mem       loss  Instances       Size
#      26/100     0.291G     0.1856         10        224: 100%|██████████| 1206/1206 [03:06<00:00,  6.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:33<00:00,  5.09it/s]
#                    all      0.967          1
#       Epoch    GPU_mem       loss  Instances       Size
#      27/100     0.291G      0.191         10        224: 100%|██████████| 1206/1206 [03:06<00:00,  6.47it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:33<00:00,  5.11it/s]
#                    all      0.968          1
#       Epoch    GPU_mem       loss  Instances       Size
#      28/100     0.291G     0.1805         10        224: 100%|██████████| 1206/1206 [03:06<00:00,  6.48it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:34<00:00,  4.97it/s]
#                    all      0.967          1
#       Epoch    GPU_mem       loss  Instances       Size
#      29/100     0.291G     0.1819         10        224: 100%|██████████| 1206/1206 [03:03<00:00,  6.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:34<00:00,  5.00it/s]
#                    all      0.968          1
#       Epoch    GPU_mem       loss  Instances       Size
#      30/100     0.291G      0.178         10        224: 100%|██████████| 1206/1206 [03:07<00:00,  6.45it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:33<00:00,  5.13it/s]
#                    all      0.969          1
#       Epoch    GPU_mem       loss  Instances       Size
#      31/100     0.291G     0.1771         10        224: 100%|██████████| 1206/1206 [03:05<00:00,  6.50it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:33<00:00,  5.19it/s]
#                    all      0.969          1
#       Epoch    GPU_mem       loss  Instances       Size
#      32/100     0.291G     0.1776         10        224: 100%|██████████| 1206/1206 [03:04<00:00,  6.54it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:36<00:00,  4.79it/s]
#                    all      0.969          1
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 22, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 32 epochs completed in 2.014 hours.
# Optimizer stripped from runs/classify/train4/weights/last.pt, 3.0MB
# Optimizer stripped from runs/classify/train4/weights/best.pt, 3.0MB
#
# Validating runs/classify/train4/weights/best.pt...
# Ultralytics 8.3.167 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,437,442 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/drive/MyDrive/hackathon/datasets/train... found 19290 images in 2 classes ✅
# val: /content/drive/MyDrive/hackathon/datasets/val... found 5512 images in 2 classes ✅
# test: /content/drive/MyDrive/hackathon/datasets/test... found 2756 images in 2 classes ✅
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:54<00:00,  3.18it/s]
#                    all       0.97          1
# Speed: 0.1ms preprocess, 0.3ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/train4

# %%
def evaluate_model(model_path, test_data_path):
    """
    Evaluate trained model on test set
    """
    # Load trained model
    model = YOLO(model_path)

    # Validate on test set
    results = model.val(data=test_data_path, split='test')

    print(f"Test Accuracy: {results.top1:.4f}")
    print(f"Test Top-5 Accuracy: {results.top5:.4f}")

    return results

# %%
test_results = evaluate_model('/content/drive/MyDrive/hackathon/runs/classify/train4/weights/best.pt',
                             '/content/drive/MyDrive/hackathon/datasets')
# Out:
# Ultralytics 8.3.167 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-cls summary (fused): 30 layers, 1,437,442 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/drive/MyDrive/hackathon/datasets/train... found 19290 images in 2 classes ✅
# val: /content/drive/MyDrive/hackathon/datasets/val... found 5512 images in 2 classes ✅
# test: /content/drive/MyDrive/hackathon/datasets/test... found 2756 images in 2 classes ✅
# test: Fast image access ✅ (ping: 0.4±0.0 ms, read: 8.0±4.5 MB/s, size: 11.6 KB)
# test: Scanning /content/drive/MyDrive/hackathon/datasets/test... 2756 images, 0 corrupt: 100%|██████████| 2756/2756 [00:13<00:00, 205.31it/s]
# test: New cache created: /content/drive/MyDrive/hackathon/datasets/test.cache
#                classes   top1_acc   top5_acc: 100%|██████████| 173/173 [00:17<00:00,  9.66it/s]
#                    all      0.964          1
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# Test Accuracy: 0.9637
# Test Top-5 Accuracy: 1.0000

# %%
def create_confusion_matrix(model_path, test_dir):
    """
    Create confusion matrix for the trained model
    """
    model = YOLO(model_path)

    # Get predictions for test set
    test_parasitized = os.path.join(test_dir, 'test', 'Parasitized')
    test_uninfected = os.path.join(test_dir, 'test', 'Uninfected')

    y_true = []
    y_pred = []

    # Process Parasitized images
    for img_name in os.listdir(test_parasitized):
        img_path = os.path.join(test_parasitized, img_name)
        results = model(img_path)
        predicted_class = results[0].names[results[0].probs.top1]
        y_true.append('Parasitized')
        y_pred.append(predicted_class)

    # Process Uninfected images
    for img_name in os.listdir(test_uninfected):
        img_path = os.path.join(test_uninfected, img_name)
        results = model(img_path)
        predicted_class = results[0].names[results[0].probs.top1]
        y_true.append('Uninfected')
        y_pred.append(predicted_class)

    # Create confusion matrix
    cm = confusion_matrix(y_true, y_pred, labels=['Parasitized', 'Uninfected'])

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Parasitized', 'Uninfected'],
                yticklabels=['Parasitized', 'Uninfected'])
    plt.title('Confusion Matrix - Malaria Classification')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

    return cm

# %%
cm = create_confusion_matrix('/content/drive/MyDrive/hackathon/runs/classify/train4/weights/best.pt',
                             '/content/drive/MyDrive/hackathon/datasets')
# Out:
# Streaming output truncated to the last 5000 lines.
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_132.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.4ms
# Speed: 2.5ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C175P136NThinF_IMG_20151127_141428_cell_213.png: 224x224 Parasitized 0.86, Uninfected 0.14, 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_144727_cell_124.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.2ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C82P43ThinF_IMG_20150817_124418_cell_172.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.9ms
# Speed: 2.5ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_172257_cell_186.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.1ms
# Speed: 5.3ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C92P53ThinF_IMG_20150821_150457_cell_252.png: 224x224 Parasitized 0.99, Uninfected 0.01, 4.5ms
# Speed: 2.8ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C175P136NThinF_IMG_20151127_142326_cell_233.png: 224x224 Parasitized 0.96, Uninfected 0.04, 3.8ms
# Speed: 3.8ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_134712_cell_56.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 2.7ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C149P110ThinF_IMG_20151115_114729_cell_272.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.0ms
# Speed: 2.6ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C167P128ReThinF_IMG_20151201_105354_cell_238.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.5ms
# Speed: 2.5ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_134944_cell_5.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.8ms
# Speed: 2.5ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_112858_cell_166.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.9ms
# Speed: 2.2ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C168P129ThinF_IMG_20151118_154126_cell_162.png: 224x224 Parasitized 0.81, Uninfected 0.19, 3.9ms
# Speed: 2.4ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C137P98ThinF_IMG_20151005_162010_cell_88.png: 224x224 Parasitized 0.99, Uninfected 0.01, 3.9ms
# Speed: 2.2ms preprocess, 3.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_114609_cell_19.png: 224x224 Uninfected 0.92, Parasitized 0.08, 3.8ms
# Speed: 2.3ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_134112_cell_138.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.1ms
# Speed: 2.6ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_104334_cell_8.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.1ms
# Speed: 2.7ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C93P54ThinF_IMG_20150821_162901_cell_195.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.0ms
# Speed: 2.0ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_114804_cell_2.png: 224x224 Parasitized 0.99, Uninfected 0.01, 3.8ms
# Speed: 2.4ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C48P9thinF_IMG_20150721_162732_cell_6.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.5ms
# Speed: 2.8ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C80P41ThinF_IMG_20150817_110957_cell_139.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.9ms
# Speed: 2.5ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C126P87ThinF_IMG_20151004_104408_cell_166.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.3ms
# Speed: 2.7ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C80P41ThinF_IMG_20150817_111246_cell_136.png: 224x224 Parasitized 0.98, Uninfected 0.02, 3.6ms
# Speed: 3.1ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C84P45ThinF_IMG_20150818_104849_cell_9.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.2ms
# Speed: 2.2ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C82P43ThinF_IMG_20150817_123652_cell_214.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.3ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C60P21thinF_IMG_20150804_105034_cell_111.png: 224x224 Parasitized 0.51, Uninfected 0.49, 3.1ms
# Speed: 2.3ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C137P98ThinF_IMG_20151005_160918_cell_73.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.8ms
# Speed: 2.2ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_113842_cell_16.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.6ms
# Speed: 2.4ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C66P27N_ThinF_IMG_20150818_163419_cell_193.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.2ms
# Speed: 2.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_110435_cell_99.png: 224x224 Parasitized 0.81, Uninfected 0.19, 3.9ms
# Speed: 2.3ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C116P77ThinF_IMG_20150930_171954_cell_83.png: 224x224 Parasitized 0.98, Uninfected 0.02, 4.2ms
# Speed: 2.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_134306_cell_138.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.0ms
# Speed: 2.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C108P69ThinF_IMG_20150924_225004_cell_222.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.1ms
# Speed: 2.6ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_111723_cell_97.png: 224x224 Parasitized 0.91, Uninfected 0.09, 3.5ms
# Speed: 2.6ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C60P21thinF_IMG_20150803_144003_cell_133.png: 224x224 Parasitized 0.52, Uninfected 0.48, 3.7ms
# Speed: 2.4ms preprocess, 3.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C183P144NThinF_IMG_20151201_222119_cell_143.png: 224x224 Uninfected 0.75, Parasitized 0.25, 4.1ms
# Speed: 4.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C117P78ThinF_IMG_20150930_214941_cell_83.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.1ms
# Speed: 2.7ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C81P42ThinF_IMG_20150817_120351_cell_181.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.5ms
# Speed: 3.3ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C176P137NThinF_IMG_20151201_121303_cell_109.png: 224x224 Parasitized 0.99, Uninfected 0.01, 4.3ms
# Speed: 3.2ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C180P141NThinF_IMG_20151201_170021_cell_37.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.1ms
# Speed: 2.5ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C88P49ThinF_IMG_20150820_151626_cell_188.png: 224x224 Parasitized 0.62, Uninfected 0.38, 4.1ms
# Speed: 2.3ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C91P52ThinF_IMG_20150821_124311_cell_24.png: 224x224 Parasitized 0.99, Uninfected 0.01, 3.5ms
# Speed: 2.5ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C117P78ThinF_IMG_20150930_222228_cell_82.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.2ms
# Speed: 2.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C116P77ThinF_IMG_20150930_171635_cell_110.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.5ms preprocess, 3.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C82P43ThinF_IMG_20150817_123652_cell_220.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.3ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_144727_cell_106.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.5ms
# Speed: 2.6ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C48P9thinF_IMG_20150721_162732_cell_1.png: 224x224 Parasitized 0.77, Uninfected 0.23, 3.8ms
# Speed: 2.4ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C101P62ThinF_IMG_20150918_151335_cell_76.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.8ms
# Speed: 2.4ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C118P79ThinF_IMG_20151002_105827_cell_155.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.2ms
# Speed: 2.8ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C81P42ThinF_IMG_20150817_120712_cell_157.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.3ms
# Speed: 2.7ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C125P86ThinF_IMG_20151004_101158_cell_154.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.9ms
# Speed: 4.3ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C80P41ThinF_IMG_20150817_111802_cell_25.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.2ms
# Speed: 3.1ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C47P8thin_Original_Motic_IMG_20150714_093512_cell_170.png: 224x224 Parasitized 0.99, Uninfected 0.01, 3.4ms
# Speed: 2.0ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_102543_cell_168.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.8ms
# Speed: 3.3ms preprocess, 3.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C91P52ThinF_IMG_20150821_124937_cell_218.png: 224x224 Parasitized 0.99, Uninfected 0.01, 6.3ms
# Speed: 2.7ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C132P93ThinF_IMG_20151004_152642_cell_26.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.3ms
# Speed: 2.5ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C48P9thinF_IMG_20150721_164031_cell_17.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.3ms
# Speed: 2.6ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_112733_cell_190.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.2ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C118P79ThinF_IMG_20151002_104831_cell_163.png: 224x224 Parasitized 0.85, Uninfected 0.15, 3.8ms
# Speed: 4.0ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C45P6ThinF_IMG_20151130_160409_cell_201.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.6ms
# Speed: 2.6ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C175P136NThinF_IMG_20151127_141325_cell_228.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.8ms
# Speed: 2.5ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C82P43ThinF_IMG_20150817_124728_cell_12.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.5ms
# Speed: 2.5ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C128P89ThinF_IMG_20151004_131632_cell_167.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.5ms
# Speed: 2.5ms preprocess, 3.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141314_cell_105.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.9ms
# Speed: 2.4ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C189P150ThinF_IMG_20151203_142113_cell_91.png: 224x224 Parasitized 0.98, Uninfected 0.02, 3.7ms
# Speed: 2.4ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C180P141NThinF_IMG_20151201_165659_cell_37.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.3ms
# Speed: 2.4ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C181P142ThinF_IMG_20151127_160650_cell_180.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.5ms
# Speed: 2.4ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C109P70ThinF_IMG_20150930_103214_cell_185.png: 224x224 Parasitized 0.89, Uninfected 0.11, 3.9ms
# Speed: 2.3ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C48P9thinF_IMG_20150721_164031_cell_8.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.0ms
# Speed: 2.7ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C132P93ThinF_IMG_20151004_152642_cell_44.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.3ms
# Speed: 2.2ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C101P62ThinF_IMG_20150923_170246_cell_78.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.9ms
# Speed: 2.2ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C51AP12thinF_IMG_20150724_153313_cell_109.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.3ms
# Speed: 2.5ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_110435_cell_112.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.4ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C147P108ThinF_IMG_20151115_092605_cell_226.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.0ms
# Speed: 2.3ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C70P31_ThinF_IMG_20150819_142744_cell_93.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.0ms
# Speed: 2.3ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C51AP12thinF_IMG_20150724_162636_cell_79.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.6ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_133329_cell_100.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.0ms
# Speed: 2.3ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C175P136NThinF_IMG_20151127_142326_cell_221.png: 224x224 Parasitized 0.98, Uninfected 0.02, 4.0ms
# Speed: 2.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C132P93ThinF_IMG_20151004_152045_cell_144.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.4ms
# Speed: 2.3ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C97P58ThinF_IMG_20150917_151320_cell_154.png: 224x224 Uninfected 0.93, Parasitized 0.07, 3.7ms
# Speed: 7.7ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_113809_cell_2.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.5ms
# Speed: 2.7ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C101P62ThinF_IMG_20150918_151335_cell_53.png: 224x224 Parasitized 0.99, Uninfected 0.01, 4.3ms
# Speed: 5.0ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C102P63ThinF_IMG_20150918_162051_cell_144.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.9ms
# Speed: 2.4ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C45P6ThinF_IMG_20151130_155011_cell_172.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.0ms
# Speed: 2.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_111942_cell_12.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.3ms
# Speed: 2.9ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C137P98ThinF_IMG_20151005_162648_cell_9.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.9ms
# Speed: 2.6ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C176P137NThinF_IMG_20151201_121808_cell_130.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.3ms
# Speed: 3.8ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C187P148NThinF_IMG_20151203_153410_cell_149.png: 224x224 Uninfected 0.56, Parasitized 0.44, 4.5ms
# Speed: 5.9ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C49P10thinF_IMG_20150724_102330_cell_233.png: 224x224 Uninfected 0.85, Parasitized 0.15, 8.5ms
# Speed: 2.4ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C118P79ThinF_IMG_20151002_104831_cell_144.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C78P39ThinF_IMG_20150606_104106_cell_172.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_103114_cell_171.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.0ms
# Speed: 2.6ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_105102_cell_105.png: 224x224 Parasitized 0.99, Uninfected 0.01, 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_133236_cell_139.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.7ms
# Speed: 2.5ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C132P93ThinF_IMG_20151004_152642_cell_12.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.4ms
# Speed: 2.4ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C157P118ThinF_IMG_20151115_163915_cell_172.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.8ms
# Speed: 4.7ms preprocess, 4.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C119P80ThinF_IMG_20151002_123608_cell_153.png: 224x224 Parasitized 0.98, Uninfected 0.02, 4.9ms
# Speed: 2.5ms preprocess, 4.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C175P136NThinF_IMG_20151127_141253_cell_239.png: 224x224 Uninfected 0.98, Parasitized 0.02, 3.7ms
# Speed: 2.7ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_112733_cell_172.png: 224x224 Parasitized 0.99, Uninfected 0.01, 3.6ms
# Speed: 1.9ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_111333_cell_167.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_104153_cell_156.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C163P124ThinF_IMG_20151116_111925_cell_282.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.3ms
# Speed: 2.2ms preprocess, 9.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C46P7ThinF_IMG_20151130_210309_cell_162.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.9ms
# Speed: 2.5ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C179P140ThinF_IMG_20151127_153819_cell_178.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.3ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C137P98ThinF_IMG_20151005_163946_cell_10.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.6ms
# Speed: 2.4ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C137P98ThinF_IMG_20151005_163946_cell_15.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.1ms
# Speed: 2.3ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C133P94ThinF_IMG_20151004_155912_cell_16.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 2.4ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C118P79ThinF_IMG_20151002_110834_cell_151.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.0ms
# Speed: 2.4ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C91P52ThinF_IMG_20150821_124937_cell_198.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_172057_cell_155.png: 224x224 Parasitized 0.93, Uninfected 0.07, 4.2ms
# Speed: 2.5ms preprocess, 4.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_143743_cell_120.png: 224x224 Parasitized 0.96, Uninfected 0.04, 7.7ms
# Speed: 2.3ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C176P137NThinF_IMG_20151201_120845_cell_131.png: 224x224 Parasitized 0.95, Uninfected 0.05, 4.0ms
# Speed: 2.5ms preprocess, 4.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141620_cell_12.png: 224x224 Parasitized 0.97, Uninfected 0.03, 4.1ms
# Speed: 2.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C76P37ThinF_IMG_20150815_171454_cell_256.png: 224x224 Parasitized 0.96, Uninfected 0.04, 4.7ms
# Speed: 2.7ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C116P77ThinF_IMG_20150930_171558_cell_109.png: 224x224 Parasitized 0.58, Uninfected 0.42, 5.9ms
# Speed: 2.3ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C156P117ThinF_IMG_20151115_154022_cell_280.png: 224x224 Parasitized 0.99, Uninfected 0.01, 5.5ms
# Speed: 2.5ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_104153_cell_129.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.7ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C50P11thinF_IMG_20150724_120553_cell_144.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.9ms
# Speed: 2.6ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C82P43ThinF_IMG_20150817_123652_cell_219.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.2ms
# Speed: 2.6ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C186P147NThinF_IMG_20151203_150557_cell_184.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.2ms
# Speed: 3.2ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_133350_cell_170.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.2ms
# Speed: 2.7ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C60P21thinF_IMG_20150804_105034_cell_127.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.1ms
# Speed: 2.5ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141314_cell_127.png: 224x224 Parasitized 0.99, Uninfected 0.01, 3.6ms
# Speed: 2.6ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_142128_cell_105.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.0ms
# Speed: 2.7ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C168P129ThinF_IMG_20151118_153739_cell_166.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C189P150ThinF_IMG_20151203_142224_cell_94.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.9ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_104334_cell_41.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.6ms
# Speed: 2.5ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C82P43ThinF_IMG_20150817_125326_cell_10.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.8ms
# Speed: 2.3ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_104030_cell_33.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.6ms
# Speed: 2.3ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C131P92ThinF_IMG_20151004_145224_cell_134.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.1ms
# Speed: 2.4ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C45P6ThinF_IMG_20151130_155110_cell_198.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.6ms
# Speed: 2.3ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C189P150ThinF_IMG_20151203_141901_cell_78.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.0ms
# Speed: 2.4ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_140538_cell_98.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.5ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_133921_cell_100.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.6ms
# Speed: 2.7ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C170P131ThinF_IMG_20151119_120111_cell_230.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.2ms
# Speed: 2.6ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_144449_cell_24.png: 224x224 Parasitized 0.98, Uninfected 0.02, 3.5ms
# Speed: 2.4ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C103P64ThinF_IMG_20150918_165510_cell_183.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.4ms
# Speed: 3.3ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C169P130ThinF_IMG_20151119_144354_cell_274.png: 224x224 Parasitized 0.99, Uninfected 0.01, 4.1ms
# Speed: 2.7ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_103326_cell_143.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.6ms
# Speed: 2.6ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C181P142ThinF_IMG_20151127_160650_cell_173.png: 224x224 Parasitized 0.89, Uninfected 0.11, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_172057_cell_150.png: 224x224 Parasitized 0.95, Uninfected 0.05, 3.7ms
# Speed: 2.7ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_104440_cell_33.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.8ms
# Speed: 2.8ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C60P21thinF_IMG_20150804_113011_cell_14.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.6ms
# Speed: 2.5ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C157P118ThinF_IMG_20151115_163915_cell_173.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.6ms
# Speed: 2.8ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C132P93ThinF_IMG_20151004_152642_cell_53.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.3ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_133.png: 224x224 Parasitized 1.00, Uninfected 0.00, 10.1ms
# Speed: 2.3ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C175P136NThinF_IMG_20151127_142326_cell_240.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.4ms
# Speed: 2.4ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C183P144NThinF_IMG_20151201_224107_cell_120.png: 224x224 Parasitized 0.97, Uninfected 0.03, 3.5ms
# Speed: 2.3ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C82P43ThinF_IMG_20150817_123824_cell_207.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.0ms
# Speed: 2.6ms preprocess, 4.0ms inference, 4.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C189P150ThinF_IMG_20151203_141901_cell_80.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.3ms
# Speed: 8.0ms preprocess, 8.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C91P52ThinF_IMG_20150821_125256_cell_12.png: 224x224 Parasitized 0.95, Uninfected 0.05, 4.6ms
# Speed: 2.6ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_134712_cell_65.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.5ms
# Speed: 3.0ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_112858_cell_156.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.4ms
# Speed: 2.5ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C118P79ThinF_IMG_20151002_105827_cell_143.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C164P125ThinF_IMG_20151116_115650_cell_164.png: 224x224 Parasitized 0.84, Uninfected 0.16, 8.7ms
# Speed: 2.8ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C70P31_ThinF_IMG_20150813_131924_cell_9.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.9ms
# Speed: 2.5ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C76P37ThinF_IMG_20150815_172902_cell_212.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.0ms
# Speed: 2.6ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C145P106ThinF_IMG_20151016_154309_cell_151.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.9ms
# Speed: 3.1ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_113446_cell_13.png: 224x224 Uninfected 0.73, Parasitized 0.27, 3.7ms
# Speed: 2.4ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_105803_cell_105.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.8ms
# Speed: 2.5ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C51AP12thinF_IMG_20150724_155557_cell_77.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.0ms
# Speed: 2.9ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_113430_cell_39.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.8ms
# Speed: 2.4ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_134112_cell_148.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.4ms
# Speed: 2.6ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C180P141NThinF_IMG_20151201_165423_cell_175.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.4ms
# Speed: 2.4ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C60P21thinF_IMG_20150804_105034_cell_124.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.0ms
# Speed: 2.8ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C101P62ThinF_IMG_20150923_170344_cell_78.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.6ms
# Speed: 2.3ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C167P128ReThinF_IMG_20151201_105559_cell_230.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.5ms
# Speed: 2.6ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C137P98ThinF_IMG_20151005_163335_cell_6.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.7ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_110900_cell_7.png: 224x224 Parasitized 0.99, Uninfected 0.01, 8.4ms
# Speed: 2.4ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141129_cell_123.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.0ms
# Speed: 5.7ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_104030_cell_22.png: 224x224 Parasitized 0.94, Uninfected 0.06, 6.7ms
# Speed: 3.1ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C88P49ThinF_IMG_20150820_150724_cell_244.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.6ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C70P31_ThinF_IMG_20150813_131330_cell_99.png: 224x224 Parasitized 0.93, Uninfected 0.07, 3.4ms
# Speed: 2.3ms preprocess, 3.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_111244_cell_165.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.5ms
# Speed: 2.6ms preprocess, 3.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C80P41ThinF_IMG_20150817_111121_cell_154.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C80P41ThinF_IMG_20150817_111943_cell_10.png: 224x224 Parasitized 0.98, Uninfected 0.02, 3.7ms
# Speed: 2.7ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_134326_cell_166.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.8ms
# Speed: 2.8ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C144P105ThinF_IMG_20151015_160529_cell_277.png: 224x224 Parasitized 0.99, Uninfected 0.01, 12.0ms
# Speed: 3.6ms preprocess, 12.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_141803_cell_122.png: 224x224 Uninfected 0.82, Parasitized 0.18, 11.7ms
# Speed: 3.9ms preprocess, 11.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_172257_cell_195.png: 224x224 Parasitized 0.97, Uninfected 0.03, 4.1ms
# Speed: 2.3ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C141P102ThinF_IMG_20151005_214208_cell_108.png: 224x224 Parasitized 1.00, Uninfected 0.00, 17.7ms
# Speed: 9.2ms preprocess, 17.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_172257_cell_150.png: 224x224 Uninfected 0.89, Parasitized 0.11, 3.7ms
# Speed: 3.2ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C70P31_ThinF_IMG_20150819_142703_cell_12.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.9ms
# ...
# Speed: 2.5ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C49P10thinF_IMG_20150724_102951_cell_122.png: 224x224 Uninfected 0.98, Parasitized 0.02, 3.9ms
# Speed: 2.3ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C94P55ThinF_IMG_20150821_170403_cell_46.png: 224x224 Uninfected 0.91, Parasitized 0.09, 3.5ms
# Speed: 2.7ms preprocess, 3.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C163P124ThinF_IMG_20151116_111925_cell_51.png: 224x224 Uninfected 0.95, Parasitized 0.05, 3.2ms
# Speed: 2.4ms preprocess, 3.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C139P100ThinF_IMG_20151005_182410_cell_117.png: 224x224 Uninfected 0.98, Parasitized 0.02, 3.7ms
# Speed: 2.5ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C67P28N_ThinF_IMG_20150819_133000_cell_143.png: 224x224 Uninfected 0.91, Parasitized 0.09, 3.7ms
# Speed: 2.5ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C79P40ThinF_IMG_20150817_102702_cell_64.png: 224x224 Parasitized 0.89, Uninfected 0.11, 3.9ms
# Speed: 2.3ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C117P78ThinF_IMG_20150930_221812_cell_61.png: 224x224 Uninfected 0.99, Parasitized 0.01, 4.4ms
# Speed: 2.8ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C133P94ThinF_IMG_20151004_155331_cell_21.png: 224x224 Uninfected 0.99, Parasitized 0.01, 3.9ms
# Speed: 2.8ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C63P24N_ThinF_IMG_20150818_144456_cell_88.png: 224x224 Uninfected 0.93, Parasitized 0.07, 5.8ms
# Speed: 2.5ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C91P52ThinF_IMG_20150821_123314_cell_93.png: 224x224 Uninfected 0.96, Parasitized 0.04, 4.6ms
# Speed: 2.5ms preprocess, 4.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C53P14thinF_IMG_20150726_115457_cell_29.png: 224x224 Uninfected 0.99, Parasitized 0.01, 3.9ms
# Speed: 2.6ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C182P143NThinF_IMG_20151201_172524_cell_26.png: 224x224 Uninfected 0.89, Parasitized 0.11, 4.4ms
# Speed: 2.4ms preprocess, 4.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C230ThinF_IMG_20151112_150621_cell_249.png: 224x224 Uninfected 1.00, Parasitized 0.00, 3.7ms
# Speed: 2.5ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C214ThinF_IMG_20151106_115440_cell_195.png: 224x224 Uninfected 0.97, Parasitized 0.03, 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C207ThinF_IMG_20151029_144152_cell_101.png: 224x224 Uninfected 0.93, Parasitized 0.07, 3.6ms
# Speed: 2.6ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C57P18thinF_IMG_20150729_110305_cell_152.png: 224x224 Uninfected 0.96, Parasitized 0.04, 4.5ms
# Speed: 2.7ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C5NThinF_IMG_20150609_122034_cell_225.png: 224x224 Uninfected 0.96, Parasitized 0.04, 3.9ms
# Speed: 3.0ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C90P51ThinF_IMG_20150821_120044_cell_220.png: 224x224 Uninfected 0.98, Parasitized 0.02, 3.6ms
# Speed: 1.9ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C86P47ThinF_IMG_20150820_124259_cell_194.png: 224x224 Uninfected 0.96, Parasitized 0.04, 4.1ms
# Speed: 2.8ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C109P70ThinF_IMG_20150930_103645_cell_76.png: 224x224 Uninfected 0.99, Parasitized 0.01, 4.2ms
# Speed: 2.6ms preprocess, 4.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C92P53ThinF_IMG_20150821_151722_cell_194.png: 224x224 Uninfected 0.84, Parasitized 0.16, 3.9ms
# Speed: 3.3ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C70P31_ThinF_IMG_20150813_131022_cell_54.png: 224x224 Uninfected 0.99, Parasitized 0.01, 9.6ms
# Speed: 2.7ms preprocess, 9.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C37BP2_thinF_IMG_20150620_133238a_cell_64.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.9ms
# Speed: 2.7ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C120P81ThinF_IMG_20151002_130715_cell_51.png: 224x224 Uninfected 0.99, Parasitized 0.01, 3.5ms
# Speed: 2.4ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C211ThinF_IMG_20151029_164248_cell_167.png: 224x224 Uninfected 0.99, Parasitized 0.01, 3.9ms
# Speed: 2.5ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C185P146ThinF_IMG_20151203_111121_cell_176.png: 224x224 Uninfected 0.99, Parasitized 0.01, 3.9ms
# Speed: 2.4ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C69P30N_ThinF_IMG_20150819_140652_cell_17.png: 224x224 Uninfected 0.98, Parasitized 0.02, 4.5ms
# Speed: 2.7ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C108P69ThinF_IMG_20150924_224616_cell_1.png: 224x224 Uninfected 0.93, Parasitized 0.07, 4.2ms
# Speed: 3.0ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C91P52ThinF_IMG_20150821_123314_cell_68.png: 224x224 Uninfected 0.93, Parasitized 0.07, 4.0ms
# Speed: 2.9ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C219ThinF_IMG_20151106_145856_cell_29.png: 224x224 Uninfected 0.97, Parasitized 0.03, 3.7ms
# Speed: 2.4ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C181P142ThinF_IMG_20151127_155914_cell_147.png: 224x224 Uninfected 0.91, Parasitized 0.09, 3.9ms
# Speed: 2.5ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C5NThinF_IMG_20150609_122006_cell_109.png: 224x224 Uninfected 0.98, Parasitized 0.02, 3.8ms
# Speed: 2.6ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C210ThinF_IMG_20151029_162834_cell_86.png: 224x224 Uninfected 0.99, Parasitized 0.01, 3.7ms
# Speed: 3.0ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C117P78ThinF_IMG_20150930_222228_cell_40.png: 224x224 Uninfected 0.95, Parasitized 0.05, 3.6ms
# Speed: 2.5ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C58P19thinF_IMG_20150802_122520_cell_161.png: 224x224 Uninfected 0.99, Parasitized 0.01, 4.7ms
# Speed: 2.5ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C180P141NThinF_IMG_20151201_163848_cell_73.png: 224x224 Uninfected 0.97, Parasitized 0.03, 3.9ms
# Speed: 4.1ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C6NThinF_IMG_20150609_122725_cell_89.png: 224x224 Uninfected 0.94, Parasitized 0.06, 8.9ms
# Speed: 2.7ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C7NthinF_IMG_20150611_105043_cell_143.png: 224x224 Uninfected 0.97, Parasitized 0.03, 4.0ms
# Speed: 2.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C73P34_ThinF_IMG_20150815_111422_cell_91.png: 224x224 Uninfected 0.96, Parasitized 0.04, 3.9ms
# Speed: 2.4ms preprocess, 3.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C151P112ThinF_IMG_20151115_121725_cell_70.png: 224x224 Uninfected 0.93, Parasitized 0.07, 5.6ms
# Speed: 2.7ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C86P47ThinF_IMG_20150820_124943_cell_3.png: 224x224 Uninfected 0.93, Parasitized 0.07, 4.3ms
# Speed: 2.5ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C215ThinF_IMG_20151106_133012_cell_77.png: 224x224 Uninfected 1.00, Parasitized 0.00, 3.9ms
# Speed: 2.5ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C213ThinF_IMG_20151106_112603_cell_214.png: 224x224 Uninfected 0.99, Parasitized 0.01, 3.1ms
# Speed: 2.5ms preprocess, 3.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C158P119ThinF_IMG_20151115_181859_cell_98.png: 224x224 Uninfected 0.94, Parasitized 0.06, 5.2ms
# Speed: 2.4ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C189P150ThinF_IMG_20151203_141455_cell_60.png: 224x224 Uninfected 0.99, Parasitized 0.01, 4.0ms
# Speed: 2.7ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C2NThinF_IMG_20150604_114751_cell_107.png: 224x224 Uninfected 0.99, Parasitized 0.01, 3.8ms
# Speed: 2.4ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C181P142ThinF_IMG_20151127_160514_cell_73.png: 224x224 Uninfected 0.93, Parasitized 0.07, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C107P68ThinF_IMG_20150924_222630_cell_105.png: 224x224 Uninfected 0.95, Parasitized 0.05, 4.0ms
# Speed: 2.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C50P11thinF_IMG_20150724_114951_cell_16.png: 224x224 Uninfected 0.91, Parasitized 0.09, 5.1ms
# Speed: 2.5ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C234ThinF_IMG_20151112_163036_cell_95.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.7ms
# Speed: 2.4ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C73P34_ThinF_IMG_20150815_111653_cell_84.png: 224x224 Uninfected 0.98, Parasitized 0.02, 4.9ms
# Speed: 3.0ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C46P7ThinF_IMG_20151130_210843_cell_61.png: 224x224 Uninfected 0.87, Parasitized 0.13, 4.1ms
# Speed: 2.7ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C45P6ThinF_IMG_20151130_155011_cell_104.png: 224x224 Uninfected 0.87, Parasitized 0.13, 3.6ms
# Speed: 3.0ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C188P149ThinF_IMG_20151203_134449_cell_36.png: 224x224 Uninfected 0.97, Parasitized 0.03, 4.2ms
# Speed: 2.3ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C240ThinF_IMG_20151127_115247_cell_5.png: 224x224 Uninfected 0.95, Parasitized 0.05, 4.0ms
# Speed: 2.2ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C80P41ThinF_IMG_20150817_110348_cell_30.png: 224x224 Uninfected 0.99, Parasitized 0.01, 3.8ms
# Speed: 2.8ms preprocess, 3.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C204ThinF_IMG_20151029_110627_cell_117.png: 224x224 Uninfected 0.97, Parasitized 0.03, 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C59P20thinF_IMG_20150803_112858_cell_138.png: 224x224 Uninfected 0.93, Parasitized 0.07, 6.7ms
# Speed: 2.7ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C162P123ThinF_IMG_20151116_102655_cell_132.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.9ms
# Speed: 2.7ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C218ThinF_IMG_20151106_144228_cell_179.png: 224x224 Parasitized 0.86, Uninfected 0.14, 3.7ms
# Speed: 2.4ms preprocess, 3.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C128P89ThinF_IMG_20151004_131231_cell_86.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.2ms
# Speed: 3.0ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)

# %%
def predict_single_image(model_path, image_path):
    """
    Predict malaria status for a single image
    """
    model = YOLO(model_path)

    # Make prediction
    results = model(image_path)

    # Get prediction details
    predicted_class = results[0].names[results[0].probs.top1]
    confidence = results[0].probs.top1conf.item()

    print(f"Image: {image_path}")
    print(f"Prediction: {predicted_class}")
    print(f"Confidence: {confidence:.4f}")

    return predicted_class, confidence

# %%
prediction, confidence = predict_single_image(
   '/content/drive/MyDrive/hackathon/runs/classify/train4/weights/best.pt',
                             '/content/drive/MyDrive/hackathon/datasets/test/Parasitized/C100P61ThinF_IMG_20150918_145422_cell_165.png')
# Out:
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C100P61ThinF_IMG_20150918_145422_cell_165.png: 224x224 Parasitized 1.00, Uninfected 0.00, 14.7ms
# Speed: 5.9ms preprocess, 14.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Image: /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C100P61ThinF_IMG_20150918_145422_cell_165.png
# Prediction: Parasitized
# Confidence: 1.0000

# %%
prediction, confidence = predict_single_image(
   '/content/drive/MyDrive/hackathon/runs/classify/train4/weights/best.pt',
                             '/content/drive/MyDrive/hackathon/datasets/test/Uninfected/C106P67ThinF_IMG_20150924_103245_cell_142.png')
# Out:
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C106P67ThinF_IMG_20150924_103245_cell_142.png: 224x224 Uninfected 0.97, Parasitized 0.03, 7.2ms
# Speed: 4.4ms preprocess, 7.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Image: /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C106P67ThinF_IMG_20150924_103245_cell_142.png
# Prediction: Uninfected
# Confidence: 0.9719

# %% [markdown]
# ##### Batch Prediction

# %%
def batch_predict(model_path, image_folder):
    """
    Predict malaria status for multiple images
    """
    model = YOLO(model_path)

    results = []
    for img_name in os.listdir(image_folder):
        if img_name.lower().endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(image_folder, img_name)
            prediction = model(img_path)

            predicted_class = prediction[0].names[prediction[0].probs.top1]
            confidence = prediction[0].probs.top1conf.item()

            results.append({
                'image': img_name,
                'prediction': predicted_class,
                'confidence': confidence
            })

    return results

# %%
batch_results = batch_predict(
    '/content/drive/MyDrive/hackathon/runs/classify/train4/weights/best.pt',
    '/content/drive/MyDrive/hackathon/datasets/test/Uninfected'
)
# Out:
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C237ThinF_IMG_20151127_104844_cell_245.png: 224x224 Uninfected 0.99, Parasitized 0.01, 6.7ms
# Speed: 3.9ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C209ThinF_IMG_20151029_160803_cell_127.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.1ms
# Speed: 3.6ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C65P26N_ThinF_IMG_20150818_154050_cell_90.png: 224x224 Uninfected 1.00, Parasitized 0.00, 3.7ms
# Speed: 2.6ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C212ThinF_IMG_20151106_110411_cell_166.png: 224x224 Uninfected 1.00, Parasitized 0.00, 4.7ms
# Speed: 2.4ms preprocess, 4.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C217ThinF_IMG_20151106_141326_cell_155.png: 224x224 Uninfected 1.00, Parasitized 0.00, 10.7ms
# Speed: 2.6ms preprocess, 10.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C141P102ThinF_IMG_20151005_215711_cell_37.png: 224x224 Uninfected 0.91, Parasitized 0.09, 6.8ms
# Speed: 5.8ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C140P101ThinF_IMG_20151005_210309_cell_103.png: 224x224 Uninfected 0.98, Parasitized 0.02, 3.7ms
# Speed: 2.6ms preprocess, 3.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C172P133ThinF_IMG_20151119_155343_cell_133.png: 224x224 Uninfected 0.99, Parasitized 0.01, 4.3ms
# Speed: 2.6ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C93P54ThinF_IMG_20150821_162901_cell_2.png: 224x224 Uninfected 0.94, Parasitized 0.06, 4.0ms
# Speed: 2.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C236ThinF_IMG_20151127_102428_cell_222.png: 224x224 Uninfected 0.99, Parasitized 0.01, 3.9ms
# Speed: 2.5ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C232ThinF_IMG_20151112_154719_cell_177.png: 224x224 Parasitized 0.93, Uninfected 0.07, 3.9ms
# Speed: 2.5ms preprocess, 3.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C66P27N_ThinF_IMG_20150818_164408_cell_4.png: 224x224 Uninfected 0.99, Parasitized 0.01, 3.7ms
# Speed: 7.8ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C155P116ThinF_IMG_20151115_142526_cell_131.png: 224x224 Uninfected 0.97, Parasitized 0.03, 4.4ms
# Speed: 6.7ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C156P117ThinF_IMG_20151115_154435_cell_192.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.7ms
# Speed: 7.1ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C183P144NThinF_IMG_20151201_223431_cell_78.png: 224x224 Uninfected 0.96, Parasitized 0.04, 6.1ms
# Speed: 3.7ms preprocess, 6.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C125P86ThinF_IMG_20151004_102132_cell_116.png: 224x224 Uninfected 0.89, Parasitized 0.11, 5.7ms
# Speed: 3.2ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C73P34_ThinF_IMG_20150815_111501_cell_34.png: 224x224 Uninfected 0.99, Parasitized 0.01, 6.5ms
# Speed: 5.4ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C160P121ThinF_IMG_20151116_093109_cell_139.png: 224x224 Parasitized 0.61, Uninfected 0.39, 5.5ms
# Speed: 3.0ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C188P149ThinF_IMG_20151203_134209_cell_122.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.3ms
# Speed: 2.4ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C170P131ThinF_IMG_20151119_115918_cell_179.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.4ms
# Speed: 2.9ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C237ThinF_IMG_20151127_104844_cell_158.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.4ms
# Speed: 2.9ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C239ThinF_IMG_20151127_113202_cell_62.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.3ms
# Speed: 3.1ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C62P23N_ThinF_IMG_20150818_133211_cell_23.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.4ms
# Speed: 3.1ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C225ThinF_IMG_20151112_113953_cell_34.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C50P11thinF_IMG_20150724_120553_cell_127.png: 224x224 Uninfected 0.95, Parasitized 0.05, 5.3ms
# Speed: 2.4ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C183P144NThinF_IMG_20151201_223431_cell_27.png: 224x224 Uninfected 0.89, Parasitized 0.11, 6.2ms
# Speed: 2.6ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C186P147NThinF_IMG_20151203_150322_cell_110.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.5ms
# Speed: 2.9ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C104P65ThinF_IMG_20150918_172214_cell_50.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.9ms
# Speed: 2.8ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C38P3thinF_original_IMG_20150621_112246_cell_166.png: 224x224 Uninfected 0.79, Parasitized 0.21, 5.5ms
# Speed: 3.1ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C146P107ThinF_IMG_20151018_135846_cell_35.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C155P116ThinF_IMG_20151115_143330_cell_152.png: 224x224 Uninfected 0.96, Parasitized 0.04, 5.6ms
# Speed: 2.6ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C164P125ThinF_IMG_20151116_114404_cell_22.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.5ms
# Speed: 2.7ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C100P61ThinF_IMG_20150918_144823_cell_21.png: 224x224 Uninfected 0.95, Parasitized 0.05, 5.3ms
# Speed: 2.8ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C203ThinF_IMG_20151029_110105_cell_246.png: 224x224 Uninfected 0.96, Parasitized 0.04, 5.3ms
# Speed: 2.9ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C151P112ThinF_IMG_20151115_121942_cell_23.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C178P139NThinF_IMG_20151201_153246_cell_127.png: 224x224 Uninfected 0.95, Parasitized 0.05, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C76P37ThinF_IMG_20150815_173019_cell_195.png: 224x224 Uninfected 0.88, Parasitized 0.12, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C182P143NThinF_IMG_20151201_171950_cell_54.png: 224x224 Uninfected 0.93, Parasitized 0.07, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C50P11thinF_IMG_20150724_115749_cell_143.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.4ms
# Speed: 2.7ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C164P125ThinF_IMG_20151116_120135_cell_46.png: 224x224 Uninfected 0.93, Parasitized 0.07, 5.2ms
# Speed: 2.4ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C132P93ThinF_IMG_20151004_151701_cell_78.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.3ms
# Speed: 2.4ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C67P28N_ThinF_IMG_20150819_121456_cell_95.png: 224x224 Uninfected 0.96, Parasitized 0.04, 5.3ms
# Speed: 2.6ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C106P67ThinF_IMG_20150924_103636_cell_99.png: 224x224 Uninfected 0.93, Parasitized 0.07, 5.8ms
# Speed: 3.0ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C74P35_ThinF_IMG_20150815_113951_cell_44.png: 224x224 Uninfected 0.99, Parasitized 0.01, 9.2ms
# Speed: 2.8ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C156P117ThinF_IMG_20151115_153831_cell_200.png: 224x224 Uninfected 1.00, Parasitized 0.00, 10.5ms
# Speed: 3.3ms preprocess, 10.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C206ThinF_IMG_20151029_141047_cell_111.png: 224x224 Uninfected 0.92, Parasitized 0.08, 5.5ms
# Speed: 5.8ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C165P126ThinF_IMG_20151117_171006_cell_120.png: 224x224 Uninfected 0.93, Parasitized 0.07, 5.6ms
# Speed: 2.9ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C158P119ThinF_IMG_20151115_181558_cell_173.png: 224x224 Uninfected 0.93, Parasitized 0.07, 5.3ms
# Speed: 2.5ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C203ThinF_IMG_20151029_105443_cell_249.png: 224x224 Uninfected 0.96, Parasitized 0.04, 5.2ms
# Speed: 2.7ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C68P29N_ThinF_IMG_20150819_133236_cell_93.png: 224x224 Uninfected 0.72, Parasitized 0.28, 5.3ms
# Speed: 2.6ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C100P61ThinF_IMG_20150918_150041_cell_12.png: 224x224 Uninfected 0.68, Parasitized 0.32, 5.4ms
# Speed: 2.7ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C91P52ThinF_IMG_20150821_125154_cell_101.png: 224x224 Uninfected 0.94, Parasitized 0.06, 5.6ms
# Speed: 3.1ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C230ThinF_IMG_20151112_150753_cell_143.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.4ms
# Speed: 2.7ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C146P107ThinF_IMG_20151018_135703_cell_137.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C182P143NThinF_IMG_20151201_172216_cell_36.png: 224x224 Uninfected 0.94, Parasitized 0.06, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C111P72ThinF_IMG_20150930_112827_cell_37.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.6ms
# Speed: 2.7ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C210ThinF_IMG_20151029_162357_cell_247.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C139P100ThinF_IMG_20151005_182527_cell_124.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.5ms
# Speed: 2.9ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C13NThinF_IMG_20150614_131529_cell_224.png: 224x224 Uninfected 0.89, Parasitized 0.11, 5.5ms
# Speed: 2.8ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C79P40ThinF_IMG_20150817_104919_cell_88.png: 224x224 Uninfected 0.93, Parasitized 0.07, 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C165P126ThinF_IMG_20151117_172356_cell_139.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.5ms
# Speed: 2.5ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C112P73ThinF_IMG_20150930_131605_cell_143.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C1_thinF_IMG_20150604_104919_cell_134.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.5ms
# Speed: 2.7ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C167P128ReThinF_IMG_20151201_105707_cell_84.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.6ms
# Speed: 2.7ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C152P113ThinF_IMG_20151115_124557_cell_39.png: 224x224 Uninfected 0.99, Parasitized 0.01, 6.0ms
# Speed: 2.6ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C138P99ThinF_IMG_20151005_173241_cell_65.png: 224x224 Uninfected 0.99, Parasitized 0.01, 8.6ms
# Speed: 2.7ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C149P110ThinF_IMG_20151115_114910_cell_237.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C163P124ThinF_IMG_20151116_110818_cell_258.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C109P70ThinF_IMG_20150930_102944_cell_127.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.6ms
# Speed: 2.7ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C136P97ThinF_IMG_20151005_142437_cell_34.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.6ms
# Speed: 2.7ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C146P107ThinF_IMG_20151018_135703_cell_34.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.3ms
# Speed: 2.7ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C68P29N_ThinF_IMG_20150819_134504_cell_62.png: 224x224 Uninfected 0.93, Parasitized 0.07, 7.9ms
# Speed: 2.8ms preprocess, 7.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C105P66ThinF_IMG_20150924_095130_cell_108.png: 224x224 Uninfected 0.93, Parasitized 0.07, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C83P44ThinF_IMG_20150817_133218_cell_113.png: 224x224 Uninfected 1.00, Parasitized 0.00, 8.6ms
# Speed: 2.7ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C158P119ThinF_IMG_20151115_181136_cell_124.png: 224x224 Uninfected 0.97, Parasitized 0.03, 7.3ms
# Speed: 2.7ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C70P31_ThinF_IMG_20150813_131609_cell_49.png: 224x224 Uninfected 0.64, Parasitized 0.36, 5.9ms
# Speed: 2.9ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C78P39ThinF_IMG_20150606_104426_cell_18.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.9ms
# Speed: 2.7ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C207ThinF_IMG_20151029_144152_cell_115.png: 224x224 Uninfected 0.98, Parasitized 0.02, 6.0ms
# Speed: 2.9ms preprocess, 6.0ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C93P54ThinF_IMG_20150821_163640_cell_31.png: 224x224 Uninfected 0.97, Parasitized 0.03, 6.1ms
# Speed: 2.9ms preprocess, 6.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C150P111ThinF_IMG_20151115_115950_cell_9.png: 224x224 Uninfected 0.92, Parasitized 0.08, 5.7ms
# Speed: 2.8ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C178P139NThinF_IMG_20151201_154524_cell_40.png: 224x224 Uninfected 0.50, Parasitized 0.50, 5.9ms
# Speed: 2.9ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C147P108ThinF_IMG_20151115_095606_cell_78.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.8ms
# Speed: 2.8ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C75P36_ThinF_IMG_20150815_163225_cell_62.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.9ms
# Speed: 2.8ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C59P20thinF_IMG_20150803_112858_cell_8.png: 224x224 Uninfected 0.90, Parasitized 0.10, 5.7ms
# Speed: 2.8ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C220ThinF_IMG_20151106_154533_cell_118.png: 224x224 Uninfected 1.00, Parasitized 0.00, 6.0ms
# Speed: 2.9ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C226ThinF_IMG_20151112_131731_cell_184.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.8ms
# Speed: 2.7ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C70P31_ThinF_IMG_20150813_131022_cell_84.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.8ms
# Speed: 2.8ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C104P65ThinF_IMG_20150918_172537_cell_67.png: 224x224 Uninfected 0.77, Parasitized 0.23, 5.6ms
# Speed: 3.1ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C103P64ThinF_IMG_20150918_164250_cell_28.png: 224x224 Uninfected 0.90, Parasitized 0.10, 5.8ms
# Speed: 2.7ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C92P53ThinF_IMG_20150821_151722_cell_56.png: 224x224 Uninfected 0.81, Parasitized 0.19, 5.9ms
# Speed: 2.7ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C111P72ThinF_IMG_20150930_113210_cell_18.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.7ms
# Speed: 2.5ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C69P30N_ThinF_IMG_20150819_135421_cell_148.png: 224x224 Uninfected 0.82, Parasitized 0.18, 6.5ms
# Speed: 2.9ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C98P59ThinF_IMG_20150917_153600_cell_21.png: 224x224 Uninfected 0.97, Parasitized 0.03, 11.2ms
# Speed: 4.2ms preprocess, 11.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C100P61ThinF_IMG_20150918_144104_cell_25.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.3ms
# Speed: 2.6ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C205ThinF_IMG_20151106_152003_cell_24.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.3ms
# Speed: 2.5ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C186P147NThinF_IMG_20151203_150222_cell_117.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.3ms
# Speed: 2.6ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C89P50ThinF_IMG_20150820_162504_cell_28.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.5ms
# Speed: 2.8ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C168P129ThinF_IMG_20151118_153739_cell_15.png: 224x224 Uninfected 0.82, Parasitized 0.18, 5.4ms
# Speed: 2.4ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C84P45ThinF_IMG_20150818_104156_cell_76.png: 224x224 Uninfected 0.88, Parasitized 0.12, 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C157P118ThinF_IMG_20151115_163611_cell_122.png: 224x224 Uninfected 0.95, Parasitized 0.05, 5.5ms
# Speed: 2.4ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C57P18thinF_IMG_20150729_104027_cell_102.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C110P71ThinF_IMG_20150930_105925_cell_120.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C69P30N_ThinF_IMG_20150819_140143_cell_86.png: 224x224 Uninfected 0.92, Parasitized 0.08, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C221ThinF_IMG_20151106_160304_cell_4.png: 224x224 Uninfected 1.00, Parasitized 0.00, 14.6ms
# Speed: 2.5ms preprocess, 14.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C49P10thinF_IMG_20150724_102330_cell_219.png: 224x224 Uninfected 0.99, Parasitized 0.01, 12.1ms
# Speed: 3.0ms preprocess, 12.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C145P106ThinF_IMG_20151016_155121_cell_145.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C178P139NThinF_IMG_20151201_154735_cell_13.png: 224x224 Uninfected 0.84, Parasitized 0.16, 5.3ms
# Speed: 2.4ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C106P67ThinF_IMG_20150924_103636_cell_163.png: 224x224 Uninfected 0.95, Parasitized 0.05, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C113P74ThinF_IMG_20150930_134751_cell_105.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C5NThinF_IMG_20150609_122227_cell_166.png: 224x224 Uninfected 0.96, Parasitized 0.04, 5.3ms
# Speed: 2.5ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C179P140ThinF_IMG_20151127_153852_cell_5.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.3ms
# Speed: 2.5ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C62P23N_ThinF_IMG_20150818_133055_cell_59.png: 224x224 Uninfected 0.66, Parasitized 0.34, 5.5ms
# Speed: 2.5ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C47P8thinOriginalOlympusCX21_IMG_20150717_174844_cell_162.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C91P52ThinF_IMG_20150821_125154_cell_70.png: 224x224 Uninfected 0.84, Parasitized 0.16, 7.4ms
# Speed: 7.0ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C182P143NThinF_IMG_20151201_172257_cell_4.png: 224x224 Uninfected 0.91, Parasitized 0.09, 7.3ms
# Speed: 2.6ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C154P115ThinF_IMG_20151115_141336_cell_140.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C13NThinF_IMG_20150614_131457_cell_193.png: 224x224 Uninfected 0.51, Parasitized 0.49, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C65P26N_ThinF_IMG_20150818_154010_cell_66.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C42P5thin_original_IMG_20150623_134751_cell_200.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.6ms
# Speed: 2.9ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C116P77ThinF_IMG_20150930_171635_cell_10.png: 224x224 Uninfected 0.94, Parasitized 0.06, 5.5ms
# Speed: 2.7ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C150P111ThinF_IMG_20151115_115805_cell_16.png: 224x224 Uninfected 0.92, Parasitized 0.08, 5.4ms
# Speed: 2.7ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C125P86ThinF_IMG_20151004_102132_cell_74.png: 224x224 Uninfected 0.95, Parasitized 0.05, 5.4ms
# Speed: 2.9ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C84P45ThinF_IMG_20150818_101056_cell_37.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.3ms
# Speed: 2.9ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C140P101ThinF_IMG_20151005_210207_cell_108.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.7ms
# Speed: 2.6ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C89P50ThinF_IMG_20150820_162504_cell_59.png: 224x224 Uninfected 0.95, Parasitized 0.05, 5.7ms
# Speed: 3.0ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C180P141NThinF_IMG_20151201_163848_cell_121.png: 224x224 Uninfected 0.96, Parasitized 0.04, 5.6ms
# Speed: 2.9ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C105P66ThinF_IMG_20150924_094800_cell_132.png: 224x224 Uninfected 0.99, Parasitized 0.01, 6.3ms
# Speed: 2.9ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C206ThinF_IMG_20151029_140538_cell_208.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.5ms
# Speed: 2.8ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C69P30N_ThinF_IMG_20150819_140143_cell_101.png: 224x224 Uninfected 0.85, Parasitized 0.15, 5.4ms
# Speed: 2.9ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C135P96ThinF_IMG_20151005_123857_cell_144.png: 224x224 Uninfected 0.85, Parasitized 0.15, 5.4ms
# Speed: 2.9ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C232ThinF_IMG_20151112_154345_cell_110.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C218ThinF_IMG_20151106_144337_cell_165.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.3ms
# Speed: 4.2ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C60P21thinF_IMG_20150803_144510_cell_35.png: 224x224 Uninfected 0.90, Parasitized 0.10, 5.6ms
# Speed: 2.6ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C226ThinF_IMG_20151112_131622_cell_183.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.5ms
# Speed: 2.7ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C118P79ThinF_IMG_20151002_110725_cell_1.png: 224x224 Uninfected 0.95, Parasitized 0.05, 5.4ms
# Speed: 2.7ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C209ThinF_IMG_20151029_160803_cell_11.png: 224x224 Uninfected 0.84, Parasitized 0.16, 5.5ms
# Speed: 2.8ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C73P34_ThinF_IMG_20150815_112246_cell_12.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C211ThinF_IMG_20151029_164033_cell_1.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.4ms
# Speed: 2.8ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C156P117ThinF_IMG_20151115_153831_cell_148.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.8ms
# Speed: 2.9ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C139P100ThinF_IMG_20151005_182257_cell_50.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.6ms
# Speed: 2.8ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C53P14thinF_IMG_20150726_120026_cell_15.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.5ms
# Speed: 4.4ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C101P62ThinF_IMG_20150923_170344_cell_69.png: 224x224 Uninfected 0.91, Parasitized 0.09, 8.5ms
# Speed: 5.6ms preprocess, 8.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C219ThinF_IMG_20151106_145927_cell_173.png: 224x224 Uninfected 1.00, Parasitized 0.00, 11.3ms
# Speed: 5.1ms preprocess, 11.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C53P14thinF_IMG_20150726_114918_cell_15.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C37BP2_thinF_IMG_20150620_132847a_cell_50.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C174P135NThinF_IMG_20151127_135640_cell_116.png: 224x224 Uninfected 0.97, Parasitized 0.03, 6.2ms
# Speed: 2.8ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C83P44ThinF_IMG_20150817_133218_cell_129.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.5ms
# Speed: 2.7ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C181P142ThinF_IMG_20151127_160650_cell_57.png: 224x224 Uninfected 0.91, Parasitized 0.09, 5.5ms
# Speed: 2.7ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C189P150ThinF_IMG_20151203_141901_cell_35.png: 224x224 Uninfected 0.92, Parasitized 0.08, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C156P117ThinF_IMG_20151115_154313_cell_53.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.6ms
# Speed: 2.7ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C177P138NThinF_IMG_20151201_142514_cell_85.png: 224x224 Parasitized 0.78, Uninfected 0.22, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C81P42ThinF_IMG_20150817_121113_cell_154.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.6ms
# Speed: 3.1ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C64P25N_ThinF_IMG_20150818_153401_cell_133.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.6ms
# Speed: 3.9ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C163P124ThinF_IMG_20151116_111742_cell_180.png: 224x224 Uninfected 0.77, Parasitized 0.23, 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C37BP2_thinF_IMG_20150620_133238a_cell_41.png: 224x224 Uninfected 0.83, Parasitized 0.17, 5.5ms
# Speed: 2.9ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C65P26N_ThinF_IMG_20150818_154624_cell_118.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.5ms
# Speed: 2.8ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C147P108ThinF_IMG_20151115_095606_cell_86.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.5ms
# Speed: 2.4ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C103P64ThinF_IMG_20150918_165125_cell_106.png: 224x224 Uninfected 0.92, Parasitized 0.08, 5.5ms
# Speed: 2.8ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C155P116ThinF_IMG_20151115_143051_cell_123.png: 224x224 Uninfected 0.99, Parasitized 0.01, 7.8ms
# Speed: 2.5ms preprocess, 7.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C161P122ThinF_IMG_20151116_100840_cell_90.png: 224x224 Uninfected 0.95, Parasitized 0.05, 6.8ms
# Speed: 3.0ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C188P149ThinF_IMG_20151203_134419_cell_148.png: 224x224 Uninfected 0.94, Parasitized 0.06, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C71P32_ThinF_IMG_20150813_161634_cell_128.png: 224x224 Uninfected 0.77, Parasitized 0.23, 5.4ms
# Speed: 2.7ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C82P43ThinF_IMG_20150817_124010_cell_39.png: 224x224 Uninfected 0.95, Parasitized 0.05, 6.3ms
# Speed: 2.5ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C164P125ThinF_IMG_20151116_113651_cell_69.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.3ms
# Speed: 3.4ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C151P112ThinF_IMG_20151115_121843_cell_200.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C240ThinF_IMG_20151127_115247_cell_160.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.4ms
# Speed: 2.4ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C203ThinF_IMG_20151029_110105_cell_219.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.5ms
# Speed: 2.5ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C45P6ThinF_IMG_20151130_160135_cell_124.png: 224x224 Uninfected 0.63, Parasitized 0.37, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C173P134NThinF_IMG_20151130_120046_cell_93.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C94P55ThinF_IMG_20150821_170249_cell_162.png: 224x224 Uninfected 0.90, Parasitized 0.10, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C86P47ThinF_IMG_20150820_124259_cell_172.png: 224x224 Uninfected 0.89, Parasitized 0.11, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C91P52ThinF_IMG_20150821_124937_cell_173.png: 224x224 Uninfected 0.94, Parasitized 0.06, 5.7ms
# Speed: 2.8ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C141P102ThinF_IMG_20151005_214208_cell_57.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C176P137NThinF_IMG_20151201_122444_cell_104.png: 224x224 Uninfected 0.87, Parasitized 0.13, 5.5ms
# Speed: 2.4ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C204ThinF_IMG_20151029_112502_cell_161.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.0ms
# Speed: 2.5ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C49P10thinF_IMG_20150724_103054_cell_5.png: 224x224 Uninfected 0.98, Parasitized 0.02, 11.7ms
# Speed: 5.1ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C57P18thinF_IMG_20150729_110305_cell_168.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.8ms
# Speed: 2.8ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C4thin_original_IMG_20150608_170016_cell_11.png: 224x224 Uninfected 0.97, Parasitized 0.03, 4.9ms
# Speed: 2.6ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C171P132ThinF_IMG_20151119_153851_cell_95.png: 224x224 Uninfected 0.98, Parasitized 0.02, 2.7ms
# Speed: 1.7ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C57P18thinF_IMG_20150729_110457_cell_9.png: 224x224 Uninfected 0.99, Parasitized 0.01, 3.9ms
# Speed: 2.3ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C137P98ThinF_IMG_20151005_161859_cell_8.png: 224x224 Uninfected 0.59, Parasitized 0.41, 2.9ms
# Speed: 1.7ms preprocess, 2.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C178P139NThinF_IMG_20151201_151903_cell_71.png: 224x224 Uninfected 0.93, Parasitized 0.07, 2.7ms
# Speed: 1.7ms preprocess, 2.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C219ThinF_IMG_20151106_150314_cell_190.png: 224x224 Uninfected 0.98, Parasitized 0.02, 4.2ms
# Speed: 2.4ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C158P119ThinF_IMG_20151115_181136_cell_114.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.1ms
# Speed: 2.6ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# ...
# Speed: 5.2ms preprocess, 4.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C49P10thinF_IMG_20150724_102951_cell_122.png: 224x224 Uninfected 0.98, Parasitized 0.02, 10.4ms
# Speed: 3.6ms preprocess, 10.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C94P55ThinF_IMG_20150821_170403_cell_46.png: 224x224 Uninfected 0.91, Parasitized 0.09, 8.0ms
# Speed: 2.9ms preprocess, 8.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C163P124ThinF_IMG_20151116_111925_cell_51.png: 224x224 Uninfected 0.95, Parasitized 0.05, 9.5ms
# Speed: 2.9ms preprocess, 9.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C139P100ThinF_IMG_20151005_182410_cell_117.png: 224x224 Uninfected 0.98, Parasitized 0.02, 7.6ms
# Speed: 2.8ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C67P28N_ThinF_IMG_20150819_133000_cell_143.png: 224x224 Uninfected 0.91, Parasitized 0.09, 8.2ms
# Speed: 2.8ms preprocess, 8.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C79P40ThinF_IMG_20150817_102702_cell_64.png: 224x224 Parasitized 0.89, Uninfected 0.11, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C117P78ThinF_IMG_20150930_221812_cell_61.png: 224x224 Uninfected 0.99, Parasitized 0.01, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C133P94ThinF_IMG_20151004_155331_cell_21.png: 224x224 Uninfected 0.99, Parasitized 0.01, 8.2ms
# Speed: 2.7ms preprocess, 8.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C63P24N_ThinF_IMG_20150818_144456_cell_88.png: 224x224 Uninfected 0.93, Parasitized 0.07, 12.1ms
# Speed: 3.1ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C91P52ThinF_IMG_20150821_123314_cell_93.png: 224x224 Uninfected 0.96, Parasitized 0.04, 11.4ms
# Speed: 2.5ms preprocess, 11.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C53P14thinF_IMG_20150726_115457_cell_29.png: 224x224 Uninfected 0.99, Parasitized 0.01, 6.3ms
# Speed: 2.9ms preprocess, 6.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C182P143NThinF_IMG_20151201_172524_cell_26.png: 224x224 Uninfected 0.89, Parasitized 0.11, 6.2ms
# Speed: 2.6ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C230ThinF_IMG_20151112_150621_cell_249.png: 224x224 Uninfected 1.00, Parasitized 0.00, 7.4ms
# Speed: 8.1ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C214ThinF_IMG_20151106_115440_cell_195.png: 224x224 Uninfected 0.97, Parasitized 0.03, 6.1ms
# Speed: 3.0ms preprocess, 6.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C207ThinF_IMG_20151029_144152_cell_101.png: 224x224 Uninfected 0.93, Parasitized 0.07, 11.1ms
# Speed: 3.4ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C57P18thinF_IMG_20150729_110305_cell_152.png: 224x224 Uninfected 0.96, Parasitized 0.04, 3.7ms
# Speed: 3.1ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C5NThinF_IMG_20150609_122034_cell_225.png: 224x224 Uninfected 0.96, Parasitized 0.04, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C90P51ThinF_IMG_20150821_120044_cell_220.png: 224x224 Uninfected 0.98, Parasitized 0.02, 6.6ms
# Speed: 2.3ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C86P47ThinF_IMG_20150820_124259_cell_194.png: 224x224 Uninfected 0.96, Parasitized 0.04, 4.9ms
# Speed: 2.4ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C109P70ThinF_IMG_20150930_103645_cell_76.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.0ms
# Speed: 4.6ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C92P53ThinF_IMG_20150821_151722_cell_194.png: 224x224 Uninfected 0.84, Parasitized 0.16, 4.9ms
# Speed: 2.9ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C70P31_ThinF_IMG_20150813_131022_cell_54.png: 224x224 Uninfected 0.99, Parasitized 0.01, 4.4ms
# Speed: 2.3ms preprocess, 4.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C37BP2_thinF_IMG_20150620_133238a_cell_64.png: 224x224 Uninfected 0.97, Parasitized 0.03, 4.4ms
# Speed: 4.6ms preprocess, 4.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C120P81ThinF_IMG_20151002_130715_cell_51.png: 224x224 Uninfected 0.99, Parasitized 0.01, 4.5ms
# Speed: 2.7ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C211ThinF_IMG_20151029_164248_cell_167.png: 224x224 Uninfected 0.99, Parasitized 0.01, 3.9ms
# Speed: 2.6ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C185P146ThinF_IMG_20151203_111121_cell_176.png: 224x224 Uninfected 0.99, Parasitized 0.01, 7.3ms
# Speed: 4.1ms preprocess, 7.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C69P30N_ThinF_IMG_20150819_140652_cell_17.png: 224x224 Uninfected 0.98, Parasitized 0.02, 5.5ms
# Speed: 2.7ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C108P69ThinF_IMG_20150924_224616_cell_1.png: 224x224 Uninfected 0.93, Parasitized 0.07, 7.3ms
# Speed: 4.2ms preprocess, 7.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C91P52ThinF_IMG_20150821_123314_cell_68.png: 224x224 Uninfected 0.93, Parasitized 0.07, 6.7ms
# Speed: 2.9ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C219ThinF_IMG_20151106_145856_cell_29.png: 224x224 Uninfected 0.97, Parasitized 0.03, 9.4ms
# Speed: 2.4ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C181P142ThinF_IMG_20151127_155914_cell_147.png: 224x224 Uninfected 0.91, Parasitized 0.09, 5.3ms
# Speed: 10.8ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C5NThinF_IMG_20150609_122006_cell_109.png: 224x224 Uninfected 0.98, Parasitized 0.02, 7.2ms
# Speed: 6.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C210ThinF_IMG_20151029_162834_cell_86.png: 224x224 Uninfected 0.99, Parasitized 0.01, 13.8ms
# Speed: 3.4ms preprocess, 13.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C117P78ThinF_IMG_20150930_222228_cell_40.png: 224x224 Uninfected 0.95, Parasitized 0.05, 5.4ms
# Speed: 2.8ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C58P19thinF_IMG_20150802_122520_cell_161.png: 224x224 Uninfected 0.99, Parasitized 0.01, 4.0ms
# Speed: 4.5ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C180P141NThinF_IMG_20151201_163848_cell_73.png: 224x224 Uninfected 0.97, Parasitized 0.03, 5.3ms
# Speed: 4.3ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C6NThinF_IMG_20150609_122725_cell_89.png: 224x224 Uninfected 0.94, Parasitized 0.06, 10.8ms
# Speed: 9.1ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C7NthinF_IMG_20150611_105043_cell_143.png: 224x224 Uninfected 0.97, Parasitized 0.03, 7.0ms
# Speed: 2.6ms preprocess, 7.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C73P34_ThinF_IMG_20150815_111422_cell_91.png: 224x224 Uninfected 0.96, Parasitized 0.04, 6.9ms
# Speed: 2.6ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C151P112ThinF_IMG_20151115_121725_cell_70.png: 224x224 Uninfected 0.93, Parasitized 0.07, 15.7ms
# Speed: 6.2ms preprocess, 15.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C86P47ThinF_IMG_20150820_124943_cell_3.png: 224x224 Uninfected 0.93, Parasitized 0.07, 8.4ms
# Speed: 6.4ms preprocess, 8.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C215ThinF_IMG_20151106_133012_cell_77.png: 224x224 Uninfected 1.00, Parasitized 0.00, 5.3ms
# Speed: 2.7ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C213ThinF_IMG_20151106_112603_cell_214.png: 224x224 Uninfected 0.99, Parasitized 0.01, 7.9ms
# Speed: 2.5ms preprocess, 7.9ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C158P119ThinF_IMG_20151115_181859_cell_98.png: 224x224 Uninfected 0.94, Parasitized 0.06, 8.2ms
# Speed: 3.1ms preprocess, 8.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C189P150ThinF_IMG_20151203_141455_cell_60.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.0ms
# Speed: 2.6ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C2NThinF_IMG_20150604_114751_cell_107.png: 224x224 Uninfected 0.99, Parasitized 0.01, 7.7ms
# Speed: 2.6ms preprocess, 7.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C181P142ThinF_IMG_20151127_160514_cell_73.png: 224x224 Uninfected 0.93, Parasitized 0.07, 4.5ms
# Speed: 2.4ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C107P68ThinF_IMG_20150924_222630_cell_105.png: 224x224 Uninfected 0.95, Parasitized 0.05, 5.0ms
# Speed: 2.7ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C50P11thinF_IMG_20150724_114951_cell_16.png: 224x224 Uninfected 0.91, Parasitized 0.09, 5.7ms
# Speed: 2.6ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C234ThinF_IMG_20151112_163036_cell_95.png: 224x224 Uninfected 0.98, Parasitized 0.02, 4.2ms
# Speed: 3.6ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C73P34_ThinF_IMG_20150815_111653_cell_84.png: 224x224 Uninfected 0.98, Parasitized 0.02, 3.6ms
# Speed: 2.7ms preprocess, 3.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C46P7ThinF_IMG_20151130_210843_cell_61.png: 224x224 Uninfected 0.87, Parasitized 0.13, 9.1ms
# Speed: 2.8ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C45P6ThinF_IMG_20151130_155011_cell_104.png: 224x224 Uninfected 0.87, Parasitized 0.13, 3.6ms
# Speed: 2.6ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C188P149ThinF_IMG_20151203_134449_cell_36.png: 224x224 Uninfected 0.97, Parasitized 0.03, 4.6ms
# Speed: 2.4ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C240ThinF_IMG_20151127_115247_cell_5.png: 224x224 Uninfected 0.95, Parasitized 0.05, 4.9ms
# Speed: 2.3ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C80P41ThinF_IMG_20150817_110348_cell_30.png: 224x224 Uninfected 0.99, Parasitized 0.01, 5.3ms
# Speed: 2.7ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C204ThinF_IMG_20151029_110627_cell_117.png: 224x224 Uninfected 0.97, Parasitized 0.03, 7.5ms
# Speed: 2.4ms preprocess, 7.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C59P20thinF_IMG_20150803_112858_cell_138.png: 224x224 Uninfected 0.93, Parasitized 0.07, 6.2ms
# Speed: 5.9ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C162P123ThinF_IMG_20151116_102655_cell_132.png: 224x224 Uninfected 0.98, Parasitized 0.02, 18.4ms
# Speed: 2.9ms preprocess, 18.4ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C218ThinF_IMG_20151106_144228_cell_179.png: 224x224 Parasitized 0.86, Uninfected 0.14, 4.1ms
# Speed: 2.6ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Uninfected/C128P89ThinF_IMG_20151004_131231_cell_86.png: 224x224 Uninfected 0.98, Parasitized 0.02, 4.1ms
# Speed: 2.6ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)

# %%
batch_results = batch_predict(
    '/content/drive/MyDrive/hackathon/runs/classify/train4/weights/best.pt',
    '/content/drive/MyDrive/hackathon/datasets/test/Parasitized'
)
# Out:
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C48P9thinF_IMG_20150721_160406_cell_200.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.5ms
# Speed: 3.0ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C63P24N_ThinF_IMG_20150818_142948_cell_170.png: 224x224 Parasitized 0.97, Uninfected 0.03, 4.1ms
# Speed: 2.9ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C137P98ThinF_IMG_20151005_163251_cell_68.png: 224x224 Parasitized 1.00, Uninfected 0.00, 14.2ms
# Speed: 2.5ms preprocess, 14.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C180P141NThinF_IMG_20151201_164714_cell_191.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C81P42ThinF_IMG_20150817_120351_cell_185.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.5ms
# Speed: 4.2ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_133236_cell_181.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.1ms
# Speed: 2.7ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C60P21thinF_IMG_20150804_113011_cell_13.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.5ms
# Speed: 2.4ms preprocess, 3.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C180P141NThinF_IMG_20151201_165453_cell_56.png: 224x224 Parasitized 0.97, Uninfected 0.03, 3.6ms
# Speed: 2.5ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C96P57ThinF_IMG_20150824_112442_cell_195.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.8ms
# Speed: 2.3ms preprocess, 4.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_114122_cell_8.png: 224x224 Parasitized 0.98, Uninfected 0.02, 3.7ms
# Speed: 2.6ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C70P31_ThinF_IMG_20150819_141403_cell_92.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.9ms
# Speed: 2.4ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_140900_cell_119.png: 224x224 Parasitized 0.94, Uninfected 0.06, 4.3ms
# Speed: 2.5ms preprocess, 4.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C185P146ThinF_IMG_20151203_111121_cell_219.png: 224x224 Parasitized 0.99, Uninfected 0.01, 4.6ms
# Speed: 2.5ms preprocess, 4.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C91P52ThinF_IMG_20150821_124504_cell_204.png: 224x224 Parasitized 1.00, Uninfected 0.00, 17.6ms
# Speed: 6.6ms preprocess, 17.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C137P98ThinF_IMG_20151005_163218_cell_72.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.1ms
# Speed: 3.5ms preprocess, 7.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C80P41ThinF_IMG_20150817_112329_cell_27.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.7ms
# Speed: 2.7ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C89P50ThinF_IMG_20150820_162504_cell_186.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.1ms
# Speed: 5.1ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C189P150ThinF_IMG_20151203_140809_cell_125.png: 224x224 Parasitized 0.99, Uninfected 0.01, 6.8ms
# Speed: 5.7ms preprocess, 6.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_110352_cell_87.png: 224x224 Parasitized 0.98, Uninfected 0.02, 5.5ms
# Speed: 4.9ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C120P81ThinF_IMG_20151002_131120_cell_193.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_143329_cell_96.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 4.4ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C162P123ThinF_IMG_20151116_104114_cell_171.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.6ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_113632_cell_14.png: 224x224 Parasitized 1.00, Uninfected 0.00, 13.5ms
# Speed: 5.0ms preprocess, 13.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C45P6ThinF_IMG_20151130_154725_cell_187.png: 224x224 Parasitized 1.00, Uninfected 0.00, 13.4ms
# Speed: 5.6ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C137P98ThinF_IMG_20151005_163251_cell_69.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.7ms
# Speed: 2.7ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C152P113ThinF_IMG_20151115_124323_cell_161.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 2.4ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_113446_cell_8.png: 224x224 Parasitized 0.98, Uninfected 0.02, 5.4ms
# Speed: 2.7ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_113809_cell_42.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 2.7ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_140646_cell_125.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 3.2ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C67P28N_ThinF_IMG_20150819_132441_cell_172.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.6ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_133421_cell_103.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_104334_cell_21.png: 224x224 Parasitized 0.98, Uninfected 0.02, 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_133236_cell_191.png: 224x224 Parasitized 0.78, Uninfected 0.22, 10.4ms
# Speed: 5.8ms preprocess, 10.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C77P38ThinF_IMG_20150602_142303_cell_140.png: 224x224 Parasitized 0.91, Uninfected 0.09, 12.4ms
# Speed: 3.3ms preprocess, 12.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_133236_cell_165.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.8ms
# Speed: 2.7ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_144449_cell_6.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.7ms
# Speed: 2.9ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C119P80ThinF_IMG_20151002_122720_cell_161.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.7ms
# Speed: 2.9ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_171905_cell_167.png: 224x224 Parasitized 0.96, Uninfected 0.04, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C116P77ThinF_IMG_20150930_171844_cell_117.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 3.0ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C130P91ThinF_IMG_20151004_141428_cell_124.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.8ms
# Speed: 2.8ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_134625_cell_64.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.1ms
# Speed: 3.6ms preprocess, 6.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C116P77ThinF_IMG_20150930_171219_cell_90.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.8ms
# Speed: 4.8ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C116P77ThinF_IMG_20150930_171844_cell_91.png: 224x224 Uninfected 0.85, Parasitized 0.15, 6.2ms
# Speed: 6.7ms preprocess, 6.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C97P58ThinF_IMG_20150917_151320_cell_155.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.8ms
# Speed: 3.2ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C119P80ThinF_IMG_20151002_123911_cell_144.png: 224x224 Parasitized 0.91, Uninfected 0.09, 5.7ms
# Speed: 2.9ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C97P58ThinF_IMG_20150917_145555_cell_182.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.3ms
# Speed: 4.7ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_134944_cell_29.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C134P95ThinF_IMG_20151005_122552_cell_120.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.7ms
# Speed: 2.6ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C179P140ThinF_IMG_20151127_153852_cell_174.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.0ms
# Speed: 3.1ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C119P80ThinF_IMG_20151002_122720_cell_160.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.7ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C180P141NThinF_IMG_20151201_165528_cell_188.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.0ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C92P53ThinF_IMG_20150821_150457_cell_250.png: 224x224 Parasitized 0.54, Uninfected 0.46, 5.7ms
# Speed: 3.1ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_113051_cell_151.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 3.3ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C101P62ThinF_IMG_20150923_165215_cell_10.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.8ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C137P98ThinF_IMG_20151005_155444_cell_100.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.1ms
# Speed: 4.2ms preprocess, 6.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141129_cell_155.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C139P100ThinF_IMG_20151005_183601_cell_150.png: 224x224 Parasitized 0.94, Uninfected 0.06, 5.7ms
# Speed: 3.0ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C162P123ThinF_IMG_20151116_104451_cell_168.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.9ms
# Speed: 5.5ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_134830_cell_40.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.7ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C180P141NThinF_IMG_20151201_163702_cell_182.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.8ms
# Speed: 2.6ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_103326_cell_134.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C84P45ThinF_IMG_20150818_101146_cell_85.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.7ms
# Speed: 3.3ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C189P150ThinF_IMG_20151203_140809_cell_133.png: 224x224 Parasitized 0.82, Uninfected 0.18, 5.8ms
# Speed: 3.0ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C133P94ThinF_IMG_20151004_155144_cell_115.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 5.3ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C80P41ThinF_IMG_20150817_111802_cell_20.png: 224x224 Parasitized 0.99, Uninfected 0.01, 5.7ms
# Speed: 2.9ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C119P80ThinF_IMG_20151002_124425_cell_134.png: 224x224 Parasitized 0.52, Uninfected 0.48, 5.6ms
# Speed: 2.8ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C120P81ThinF_IMG_20151002_130150_cell_205.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.0ms
# Speed: 2.5ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C171P132ThinF_IMG_20151119_153150_cell_223.png: 224x224 Uninfected 0.76, Parasitized 0.24, 5.6ms
# Speed: 2.6ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_133447_cell_125.png: 224x224 Parasitized 0.78, Uninfected 0.22, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C132P93ThinF_IMG_20151004_152808_cell_11.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.8ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C91P52ThinF_IMG_20150821_124739_cell_173.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.7ms
# Speed: 2.6ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_134625_cell_33.png: 224x224 Uninfected 0.68, Parasitized 0.32, 5.4ms
# Speed: 2.7ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C181P142ThinF_IMG_20151127_160650_cell_191.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.1ms
# Speed: 2.5ms preprocess, 6.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C179P140ThinF_IMG_20151127_153420_cell_170.png: 224x224 Parasitized 0.98, Uninfected 0.02, 5.4ms
# Speed: 2.4ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C81P42ThinF_IMG_20150817_120712_cell_161.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.8ms
# Speed: 2.6ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_172057_cell_146.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C101P62ThinF_IMG_20150918_151335_cell_65.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141620_cell_57.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_172257_cell_147.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 4.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C69P30N_ThinF_IMG_20150819_135613_cell_243.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C70P31_ThinF_IMG_20150813_131022_cell_90.png: 224x224 Parasitized 0.98, Uninfected 0.02, 5.7ms
# Speed: 2.8ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141129_cell_135.png: 224x224 Parasitized 1.00, Uninfected 0.00, 12.4ms
# Speed: 3.0ms preprocess, 12.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C188P149ThinF_IMG_20151203_134419_cell_196.png: 224x224 Parasitized 0.99, Uninfected 0.01, 5.6ms
# Speed: 3.1ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C189P150ThinF_IMG_20151203_140809_cell_131.png: 224x224 Parasitized 0.99, Uninfected 0.01, 5.8ms
# Speed: 2.5ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C174P135NThinF_IMG_20151127_135640_cell_186.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.8ms
# Speed: 2.5ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C66P27N_ThinF_IMG_20150818_164754_cell_201.png: 224x224 Parasitized 0.99, Uninfected 0.01, 5.5ms
# Speed: 2.7ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_112733_cell_186.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.8ms
# Speed: 2.6ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_113051_cell_155.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.9ms
# Speed: 2.7ms preprocess, 5.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_105554_cell_8.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.7ms
# Speed: 2.8ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C85P46ThinF_IMG_20150820_105748_cell_255.png: 224x224 Parasitized 0.98, Uninfected 0.02, 5.7ms
# Speed: 2.8ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C50P11thinF_IMG_20150724_115651_cell_190.png: 224x224 Parasitized 0.99, Uninfected 0.01, 5.6ms
# Speed: 2.4ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C80P41ThinF_IMG_20150817_111121_cell_165.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C180P141NThinF_IMG_20151201_163751_cell_157.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C137P98ThinF_IMG_20151005_164119_cell_75.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C132P93ThinF_IMG_20151004_152808_cell_57.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C48P9thinF_IMG_20150721_161055_cell_191.png: 224x224 Uninfected 0.83, Parasitized 0.17, 5.4ms
# Speed: 2.5ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C84P45ThinF_IMG_20150818_101146_cell_103.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C175P136NThinF_IMG_20151127_142326_cell_232.png: 224x224 Uninfected 0.71, Parasitized 0.29, 5.6ms
# Speed: 3.0ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_104334_cell_46.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.4ms
# Speed: 4.4ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_111244_cell_169.png: 224x224 Parasitized 0.97, Uninfected 0.03, 5.3ms
# Speed: 3.1ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C51AP12thinF_IMG_20150724_154330_cell_124.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.4ms
# Speed: 5.3ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C116P77ThinF_IMG_20150930_172112_cell_81.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.7ms
# Speed: 2.5ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_133538_cell_81.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 3.2ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_102721_cell_9.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_134504_cell_110.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C149P110ThinF_IMG_20151115_114555_cell_304.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 2.5ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_134112_cell_125.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.5ms
# Speed: 2.7ms preprocess, 8.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C109P70ThinF_IMG_20150930_103113_cell_162.png: 224x224 Parasitized 0.89, Uninfected 0.11, 5.4ms
# Speed: 2.6ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_140900_cell_117.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.3ms
# Speed: 2.6ms preprocess, 5.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C102P63ThinF_IMG_20150918_162511_cell_173.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 3.1ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_171950_cell_166.png: 224x224 Uninfected 0.74, Parasitized 0.26, 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C109P70ThinF_IMG_20150930_102944_cell_172.png: 224x224 Parasitized 0.65, Uninfected 0.35, 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_113632_cell_4.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.7ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_113430_cell_7.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.0ms
# Speed: 2.7ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141351_cell_118.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C123P84ThinF_IMG_20151002_151432_cell_171.png: 224x224 Uninfected 0.64, Parasitized 0.36, 5.7ms
# Speed: 2.7ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C177P138NThinF_IMG_20151201_143704_cell_177.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.8ms
# Speed: 2.5ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C179P140ThinF_IMG_20151127_153852_cell_164.png: 224x224 Uninfected 0.74, Parasitized 0.26, 5.6ms
# Speed: 2.8ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_103824_cell_133.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.7ms
# Speed: 2.8ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C116P77ThinF_IMG_20150930_171448_cell_111.png: 224x224 Parasitized 0.55, Uninfected 0.45, 5.5ms
# Speed: 2.6ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C180P141NThinF_IMG_20151201_165528_cell_165.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.7ms
# Speed: 2.6ms preprocess, 5.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C130P91ThinF_IMG_20151004_142951_cell_152.png: 224x224 Parasitized 0.99, Uninfected 0.01, 6.0ms
# Speed: 2.6ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C76P37ThinF_IMG_20150815_172808_cell_217.png: 224x224 Parasitized 0.99, Uninfected 0.01, 5.4ms
# Speed: 2.3ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C123P84ThinF_IMG_20151002_151851_cell_175.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 2.5ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C119P80ThinF_IMG_20151002_123608_cell_154.png: 224x224 Parasitized 0.97, Uninfected 0.03, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_113842_cell_19.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.5ms
# Speed: 2.7ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_140538_cell_95.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.4ms
# Speed: 2.8ms preprocess, 5.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_134306_cell_128.png: 224x224 Parasitized 1.00, Uninfected 0.00, 15.4ms
# Speed: 2.6ms preprocess, 15.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C189P150ThinF_IMG_20151203_140902_cell_110.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.9ms
# Speed: 2.8ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C132P93ThinF_IMG_20151004_152642_cell_22.png: 224x224 Parasitized 1.00, Uninfected 0.00, 13.1ms
# Speed: 6.1ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C188P149ThinF_IMG_20151203_135433_cell_180.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.0ms
# Speed: 3.5ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_134944_cell_28.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.3ms
# Speed: 5.1ms preprocess, 8.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C188P149ThinF_IMG_20151203_135433_cell_183.png: 224x224 Parasitized 1.00, Uninfected 0.00, 14.3ms
# Speed: 5.5ms preprocess, 14.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141620_cell_53.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.6ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C117P78ThinF_IMG_20150930_214317_cell_102.png: 224x224 Uninfected 0.97, Parasitized 0.03, 4.7ms
# Speed: 2.9ms preprocess, 4.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C51AP12thinF_IMG_20150724_155947_cell_96.png: 224x224 Parasitized 0.73, Uninfected 0.27, 6.7ms
# Speed: 2.2ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C132P93ThinF_IMG_20151004_151941_cell_28.png: 224x224 Parasitized 0.92, Uninfected 0.08, 6.9ms
# Speed: 5.1ms preprocess, 6.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_103637_cell_162.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.5ms
# Speed: 3.0ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_110435_cell_88.png: 224x224 Parasitized 1.00, Uninfected 0.00, 12.5ms
# Speed: 2.6ms preprocess, 12.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C119P80ThinF_IMG_20151002_123043_cell_154.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.2ms
# Speed: 2.9ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C134P95ThinF_IMG_20151005_121834_cell_120.png: 224x224 Parasitized 0.88, Uninfected 0.12, 4.9ms
# Speed: 3.4ms preprocess, 4.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_133421_cell_101.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.0ms
# Speed: 2.8ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_112802_cell_162.png: 224x224 Parasitized 0.85, Uninfected 0.15, 4.7ms
# Speed: 2.6ms preprocess, 4.7ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C137P98ThinF_IMG_20151005_155444_cell_90.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.0ms
# Speed: 2.5ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_141946_cell_109.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.5ms
# Speed: 2.7ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C132P93ThinF_IMG_20151004_153030_cell_37.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.5ms
# Speed: 2.4ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C76P37ThinF_IMG_20150815_172902_cell_215.png: 224x224 Parasitized 0.82, Uninfected 0.18, 4.0ms
# Speed: 2.4ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C98P59ThinF_IMG_20150917_154452_cell_207.png: 224x224 Parasitized 0.94, Uninfected 0.06, 3.9ms
# Speed: 2.4ms preprocess, 3.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_133329_cell_115.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.5ms
# Speed: 2.3ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_104440_cell_20.png: 224x224 Parasitized 0.77, Uninfected 0.23, 6.0ms
# Speed: 4.0ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C130P91ThinF_IMG_20151004_135449_cell_132.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.0ms
# Speed: 2.8ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C144P105ThinF_IMG_20151015_160529_cell_270.png: 224x224 Parasitized 0.90, Uninfected 0.10, 5.6ms
# Speed: 3.0ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_134944_cell_23.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.0ms
# Speed: 2.9ms preprocess, 9.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C175P136NThinF_IMG_20151127_142009_cell_220.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.3ms
# Speed: 3.7ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_104153_cell_169.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.2ms
# Speed: 3.6ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C116P77ThinF_IMG_20150930_171844_cell_99.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.9ms
# Speed: 2.9ms preprocess, 9.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_133236_cell_141.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.7ms
# Speed: 2.3ms preprocess, 5.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C175P136NThinF_IMG_20151127_141325_cell_218.png: 224x224 Parasitized 0.74, Uninfected 0.26, 4.0ms
# Speed: 2.7ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C97P58ThinF_IMG_20150917_152032_cell_176.png: 224x224 Parasitized 1.00, Uninfected 0.00, 12.3ms
# Speed: 5.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C189P150ThinF_IMG_20151203_141308_cell_72.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.0ms
# Speed: 3.6ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C84P45ThinF_IMG_20150818_102654_cell_79.png: 224x224 Parasitized 1.00, Uninfected 0.00, 11.4ms
# Speed: 2.5ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_141803_cell_112.png: 224x224 Parasitized 0.99, Uninfected 0.01, 4.3ms
# Speed: 2.6ms preprocess, 4.3ms inference, 3.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C49P10thinF_IMG_20150724_103233_cell_201.png: 224x224 Uninfected 0.79, Parasitized 0.21, 10.7ms
# Speed: 2.4ms preprocess, 10.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141857_cell_47.png: 224x224 Parasitized 0.99, Uninfected 0.01, 9.0ms
# Speed: 2.8ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C180P141NThinF_IMG_20151201_165601_cell_195.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.9ms
# Speed: 2.4ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C175P136NThinF_IMG_20151127_141253_cell_244.png: 224x224 Parasitized 0.79, Uninfected 0.21, 3.8ms
# Speed: 2.6ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_111333_cell_183.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.8ms
# Speed: 2.5ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C93P54ThinF_IMG_20150821_163815_cell_223.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.8ms
# Speed: 2.4ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_140646_cell_109.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.7ms
# Speed: 2.6ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141520_cell_135.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.1ms
# Speed: 3.0ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_110352_cell_98.png: 224x224 Parasitized 0.99, Uninfected 0.01, 9.6ms
# Speed: 2.8ms preprocess, 9.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C89P50ThinF_IMG_20150820_162153_cell_190.png: 224x224 Parasitized 1.00, Uninfected 0.00, 11.3ms
# Speed: 2.9ms preprocess, 11.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C167P128ReThinF_IMG_20151201_105559_cell_222.png: 224x224 Parasitized 1.00, Uninfected 0.00, 10.0ms
# Speed: 7.4ms preprocess, 10.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_102543_cell_160.png: 224x224 Parasitized 1.00, Uninfected 0.00, 12.8ms
# Speed: 3.2ms preprocess, 12.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C91P52ThinF_IMG_20150821_124937_cell_221.png: 224x224 Parasitized 0.92, Uninfected 0.08, 12.9ms
# Speed: 8.2ms preprocess, 12.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_172216_cell_175.png: 224x224 Parasitized 0.83, Uninfected 0.17, 15.8ms
# Speed: 4.0ms preprocess, 15.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C84P45ThinF_IMG_20150818_101550_cell_107.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 8.8ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C180P141NThinF_IMG_20151201_165659_cell_1.png: 224x224 Parasitized 1.00, Uninfected 0.00, 11.4ms
# Speed: 2.9ms preprocess, 11.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C48P9thinF_IMG_20150721_160944_cell_211.png: 224x224 Parasitized 1.00, Uninfected 0.00, 10.1ms
# Speed: 2.8ms preprocess, 10.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_133447_cell_126.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.9ms
# Speed: 2.8ms preprocess, 9.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C91P52ThinF_IMG_20150821_123314_cell_196.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.9ms
# Speed: 2.9ms preprocess, 8.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C181P142ThinF_IMG_20151127_160539_cell_195.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.1ms
# Speed: 2.6ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C101P62ThinF_IMG_20150918_151239_cell_83.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.6ms
# ...
# Speed: 3.1ms preprocess, 8.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C84P45ThinF_IMG_20150818_102325_cell_96.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.3ms
# Speed: 3.0ms preprocess, 6.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C84P45ThinF_IMG_20150818_103817_cell_8.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.0ms
# Speed: 4.4ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C101P62ThinF_IMG_20150923_170246_cell_69.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.0ms
# Speed: 4.5ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C180P141NThinF_IMG_20151201_163702_cell_177.png: 224x224 Parasitized 0.98, Uninfected 0.02, 10.5ms
# Speed: 4.7ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C67P28N_ThinF_IMG_20150819_133000_cell_171.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.9ms
# Speed: 3.9ms preprocess, 8.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C65P26N_ThinF_IMG_20150818_154050_cell_178.png: 224x224 Parasitized 1.00, Uninfected 0.00, 11.5ms
# Speed: 4.2ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_133421_cell_106.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.0ms
# Speed: 5.4ms preprocess, 5.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C116P77ThinF_IMG_20150930_171558_cell_106.png: 224x224 Parasitized 0.98, Uninfected 0.02, 9.0ms
# Speed: 5.1ms preprocess, 9.0ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C146P107ThinF_IMG_20151018_135703_cell_226.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.6ms
# Speed: 5.7ms preprocess, 5.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_172257_cell_179.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.6ms
# Speed: 4.9ms preprocess, 7.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C60P21thinF_IMG_20150804_105034_cell_117.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.1ms
# Speed: 5.3ms preprocess, 7.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C45P6ThinF_IMG_20151130_155110_cell_200.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.4ms
# Speed: 3.8ms preprocess, 4.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C131P92ThinF_IMG_20151004_151001_cell_125.png: 224x224 Parasitized 0.93, Uninfected 0.07, 4.3ms
# Speed: 3.0ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C70P31_ThinF_IMG_20150813_131457_cell_13.png: 224x224 Parasitized 0.98, Uninfected 0.02, 12.5ms
# Speed: 2.7ms preprocess, 12.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C74P35_ThinF_IMG_20150815_121324_cell_138.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.4ms
# Speed: 4.3ms preprocess, 9.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_102721_cell_8.png: 224x224 Parasitized 1.00, Uninfected 0.00, 10.0ms
# Speed: 4.3ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_103326_cell_131.png: 224x224 Parasitized 0.99, Uninfected 0.01, 4.5ms
# Speed: 5.9ms preprocess, 4.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C101P62ThinF_IMG_20150923_165215_cell_31.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.8ms
# Speed: 6.5ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C107P68ThinF_IMG_20150924_222233_cell_161.png: 224x224 Parasitized 1.00, Uninfected 0.00, 11.7ms
# Speed: 5.0ms preprocess, 11.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C149P110ThinF_IMG_20151115_114910_cell_284.png: 224x224 Parasitized 0.99, Uninfected 0.01, 4.4ms
# Speed: 5.0ms preprocess, 4.4ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C133P94ThinF_IMG_20151004_154717_cell_128.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.7ms
# Speed: 5.6ms preprocess, 9.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_172257_cell_187.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.4ms
# Speed: 4.8ms preprocess, 5.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_172759_cell_24.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.8ms
# Speed: 2.6ms preprocess, 5.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C189P150ThinF_IMG_20151203_141406_cell_104.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.5ms
# Speed: 5.1ms preprocess, 4.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_172524_cell_165.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.1ms
# Speed: 4.1ms preprocess, 5.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C116P77ThinF_IMG_20150930_171739_cell_88.png: 224x224 Uninfected 0.60, Parasitized 0.40, 9.1ms
# Speed: 5.0ms preprocess, 9.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C177P138NThinF_IMG_20151201_143025_cell_183.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.3ms
# Speed: 3.4ms preprocess, 8.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_133236_cell_202.png: 224x224 Parasitized 1.00, Uninfected 0.00, 10.6ms
# Speed: 3.4ms preprocess, 10.6ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C118P79ThinF_IMG_20151002_105018_cell_136.png: 224x224 Parasitized 1.00, Uninfected 0.00, 12.5ms
# Speed: 3.7ms preprocess, 12.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C184P145ThinF_IMG_20151203_104334_cell_19.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.9ms
# Speed: 4.2ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_111326_cell_10.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.7ms
# Speed: 6.7ms preprocess, 6.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C39P4thinF_original_IMG_20150622_114804_cell_26.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.9ms
# Speed: 2.8ms preprocess, 9.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C133P94ThinF_IMG_20151004_154919_cell_122.png: 224x224 Parasitized 1.00, Uninfected 0.00, 13.6ms
# Speed: 3.5ms preprocess, 13.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C177P138NThinF_IMG_20151201_142514_cell_162.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.4ms
# Speed: 4.8ms preprocess, 7.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C120P81ThinF_IMG_20151002_125443_cell_131.png: 224x224 Parasitized 1.00, Uninfected 0.00, 8.2ms
# Speed: 3.9ms preprocess, 8.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C70P31_ThinF_IMG_20150813_131609_cell_102.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.1ms
# Speed: 8.5ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C91P52ThinF_IMG_20150821_125154_cell_199.png: 224x224 Parasitized 1.00, Uninfected 0.00, 10.4ms
# Speed: 3.4ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C133P94ThinF_IMG_20151004_155518_cell_101.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.4ms
# Speed: 4.4ms preprocess, 9.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_143743_cell_107.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.0ms
# Speed: 5.4ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C132P93ThinF_IMG_20151004_151811_cell_144.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.5ms
# Speed: 8.4ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_134504_cell_128.png: 224x224 Parasitized 1.00, Uninfected 0.00, 7.6ms
# Speed: 4.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C59P20thinF_IMG_20150803_115303_cell_33.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.6ms
# Speed: 8.0ms preprocess, 9.6ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C166P127ThinF_IMG_20151117_194932_cell_225.png: 224x224 Uninfected 0.87, Parasitized 0.13, 10.6ms
# Speed: 5.3ms preprocess, 10.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141857_cell_32.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.9ms
# Speed: 5.9ms preprocess, 4.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C136P97ThinF_IMG_20151005_141946_cell_95.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.0ms
# Speed: 7.6ms preprocess, 4.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C182P143NThinF_IMG_20151201_171836_cell_155.png: 224x224 Parasitized 1.00, Uninfected 0.00, 6.4ms
# Speed: 2.9ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C117P78ThinF_IMG_20150930_221048_cell_100.png: 224x224 Parasitized 1.00, Uninfected 0.00, 10.1ms
# Speed: 7.5ms preprocess, 10.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C129P90ThinF_IMG_20151004_133538_cell_76.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.2ms
# Speed: 4.8ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C133P94ThinF_IMG_20151004_154351_cell_104.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.9ms
# Speed: 6.1ms preprocess, 9.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C181P142ThinF_IMG_20151127_160539_cell_179.png: 224x224 Parasitized 1.00, Uninfected 0.00, 11.7ms
# Speed: 4.4ms preprocess, 11.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C68P29N_ThinF_IMG_20150819_133350_cell_145.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.2ms
# Speed: 4.1ms preprocess, 5.2ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C115P76ThinF_IMG_20150930_163018_cell_252.png: 224x224 Parasitized 0.85, Uninfected 0.15, 5.0ms
# Speed: 4.8ms preprocess, 5.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141857_cell_26.png: 224x224 Parasitized 1.00, Uninfected 0.00, 10.9ms
# Speed: 2.5ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C60P21thinF_IMG_20150804_105639_cell_4.png: 224x224 Parasitized 0.98, Uninfected 0.02, 9.2ms
# Speed: 4.9ms preprocess, 9.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C46P7ThinF_IMG_20151130_210743_cell_157.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.8ms
# Speed: 7.3ms preprocess, 9.8ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C46P7ThinF_IMG_20151130_210309_cell_161.png: 224x224 Parasitized 1.00, Uninfected 0.00, 5.8ms
# Speed: 5.2ms preprocess, 5.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C181P142ThinF_IMG_20151127_160616_cell_171.png: 224x224 Parasitized 1.00, Uninfected 0.00, 3.6ms
# Speed: 6.5ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C84P45ThinF_IMG_20150818_102800_cell_14.png: 224x224 Parasitized 1.00, Uninfected 0.00, 4.3ms
# Speed: 5.3ms preprocess, 4.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C99P60ThinF_IMG_20150918_141620_cell_44.png: 224x224 Parasitized 1.00, Uninfected 0.00, 10.9ms
# Speed: 4.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# image 1/1 /content/drive/MyDrive/hackathon/datasets/test/Parasitized/C133P94ThinF_IMG_20151004_153930_cell_113.png: 224x224 Parasitized 1.00, Uninfected 0.00, 9.8ms
# Speed: 4.8ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from ultralytics import YOLO
import os
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import torch
import pandas as pd
import cv2

# Load your trained model
model_path = "runs/classify/train4/weights/best.pt"
model = YOLO(model_path)

# 1. Evaluate on test set
def evaluate_test_set():
    """Evaluate the trained model on test set"""
    print("Evaluating on test set...")

    # Test on the test split
    test_results = model.val(data='/content/drive/MyDrive/hackathon/datasets',
                           split='test')

    print(f"Test Accuracy: {test_results.top1:.4f}")
    print(f"Test Loss: {test_results.fitness:.4f}")

    return test_results

def create_confusion_matrix():
    """Create confusion matrix for test set"""
    test_dir = '/content/drive/MyDrive/hackathon/datasets/test'

    y_true = []
    y_pred = []
    confidences = []

    print("Processing Parasitized images...")
    parasitized_dir = os.path.join(test_dir, 'Parasitized')
    for img_name in os.listdir(parasitized_dir):
        if img_name.lower().endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(parasitized_dir, img_name)
            results = model(img_path, verbose=False)

            predicted_class = results[0].names[results[0].probs.top1]
            confidence = results[0].probs.top1conf.item()

            y_true.append('Parasitized')
            y_pred.append(predicted_class)
            confidences.append(confidence)

    print("Processing Uninfected images...")
    uninfected_dir = os.path.join(test_dir, 'Uninfected')
    for img_name in os.listdir(uninfected_dir):
        if img_name.lower().endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(uninfected_dir, img_name)
            results = model(img_path, verbose=False)

            predicted_class = results[0].names[results[0].probs.top1]
            confidence = results[0].probs.top1conf.item()

            y_true.append('Uninfected')
            y_pred.append(predicted_class)
            confidences.append(confidence)

    cm = confusion_matrix(y_true, y_pred, labels=['Parasitized', 'Uninfected'])
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Parasitized', 'Uninfected'],
                yticklabels=['Parasitized', 'Uninfected'])
    plt.title('Confusion Matrix - Malaria Classification\nTest Set Results')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

    from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, pos_label='Parasitized')
    recall = recall_score(y_true, y_pred, pos_label='Parasitized')
    f1 = f1_score(y_true, y_pred, pos_label='Parasitized')

    print(f"\nTest Set Metrics:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")
    print(f"Average Confidence: {np.mean(confidences):.4f}")

    return cm, accuracy, precision, recall, f1

def plot_training_progress():
    """Plot training curves from results with proper column names"""


    results_path = "runs/classify/train4/results.csv"
    if os.path.exists(results_path):
        df = pd.read_csv(results_path)

        print("Available columns in results.csv:")
        print(df.columns.tolist())

        column_mapping = {
            'val/acc_top1': ['val/acc_top1', 'metrics/accuracy_top1', 'val_accuracy', 'accuracy'],
            'train/loss': ['train/loss', 'train_loss', 'loss'],
            'lr/pg0': ['lr/pg0', 'lr', 'learning_rate', 'lr0']
        }

        actual_columns = {}
        for key, possible_names in column_mapping.items():
            for name in possible_names:
                if name in df.columns:
                    actual_columns[key] = name
                    break

        print("Mapped columns:", actual_columns)

        fig, axes = plt.subplots(2, 2, figsize=(15, 10))

        if 'train/loss' in actual_columns:
            axes[0,0].plot(df['epoch'], df[actual_columns['train/loss']], label='Training Loss')
            axes[0,0].set_title('Training Loss')
            axes[0,0].set_xlabel('Epoch')
            axes[0,0].set_ylabel('Loss')
            axes[0,0].legend()
            axes[0,0].grid(True)
        else:
            axes[0,0].text(0.5, 0.5, 'Training Loss\nData Not Available',
                          ha='center', va='center', transform=axes[0,0].transAxes)

        if 'val/acc_top1' in actual_columns:
            axes[0,1].plot(df['epoch'], df[actual_columns['val/acc_top1']], label='Validation Accuracy', color='orange')
            axes[0,1].set_title('Validation Accuracy')
            axes[0,1].set_xlabel('Epoch')
            axes[0,1].set_ylabel('Accuracy')
            axes[0,1].legend()
            axes[0,1].grid(True)
        else:
            axes[0,1].text(0.5, 0.5, 'Validation Accuracy\nData Not Available',
                          ha='center', va='center', transform=axes[0,1].transAxes)

        if 'lr/pg0' in actual_columns:
            axes[1,0].plot(df['epoch'], df[actual_columns['lr/pg0']], label='Learning Rate', color='green')
            axes[1,0].set_title('Learning Rate Schedule')
            axes[1,0].set_xlabel('Epoch')
            axes[1,0].set_ylabel('Learning Rate')
            axes[1,0].legend()
            axes[1,0].grid(True)
        else:
            axes[1,0].text(0.5, 0.5, 'Learning Rate\nData Not Available',
                          ha='center', va='center', transform=axes[1,0].transAxes)

        if 'train/loss' in actual_columns and 'val/acc_top1' in actual_columns:
            ax2 = axes[1,1].twinx()
            axes[1,1].plot(df['epoch'], df[actual_columns['train/loss']], 'b-', label='Training Loss')
            ax2.plot(df['epoch'], df[actual_columns['val/acc_top1']], 'r-', label='Validation Accuracy')

            axes[1,1].set_xlabel('Epoch')
            axes[1,1].set_ylabel('Loss', color='b')
            ax2.set_ylabel('Accuracy', color='r')
            axes[1,1].legend(loc='upper left')
            ax2.legend(loc='upper right')
            axes[1,1].grid(True)
        else:
            axes[1,1].text(0.5, 0.5, 'Combined Plot\nData Not Available',
                          ha='center', va='center', transform=axes[1,1].transAxes)

        plt.tight_layout()
        plt.show()
    else:
        print(f"Results file not found: {results_path}")

def test_sample_predictions():
    """Test model on sample images"""
    test_dir = '/content/drive/MyDrive/hackathon/datasets/test'

    parasitized_imgs = os.listdir(os.path.join(test_dir, 'Parasitized'))[:5]
    uninfected_imgs = os.listdir(os.path.join(test_dir, 'Uninfected'))[:5]

    fig, axes = plt.subplots(2, 5, figsize=(20, 8))

    for i, img_name in enumerate(parasitized_imgs):
        img_path = os.path.join(test_dir, 'Parasitized', img_name)
        results = model(img_path, verbose=False)

        predicted_class = results[0].names[results[0].probs.top1]
        confidence = results[0].probs.top1conf.item()

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        axes[0,i].imshow(img)
        color = 'green' if predicted_class == 'Parasitized' else 'red'
        axes[0,i].set_title(f'True: Parasitized\nPred: {predicted_class}\nConf: {confidence:.3f}',
                           color=color, fontweight='bold')
        axes[0,i].axis('off')

    for i, img_name in enumerate(uninfected_imgs):
        img_path = os.path.join(test_dir, 'Uninfected', img_name)
        results = model(img_path, verbose=False)

        predicted_class = results[0].names[results[0].probs.top1]
        confidence = results[0].probs.top1conf.item()

        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        axes[1,i].imshow(img)
        color = 'green' if predicted_class == 'Uninfected' else 'red'
        axes[1,i].set_title(f'True: Uninfected\nPred: {predicted_class}\nConf: {confidence:.3f}',
                           color=color, fontweight='bold')
        axes[1,i].axis('off')

    plt.tight_layout()
    plt.show()

def export_model():
    """Export model for different deployment scenarios"""
    print("Exporting model for deployment...")

    export_formats = [
        ('onnx', 'ONNX'),
        ('tflite', 'TensorFlow Lite'),
        ('engine', 'TensorRT'),
        ('openvino', 'OpenVINO'),
        ('coreml', 'CoreML'),
        ('paddle', 'Paddle')
    ]

    successful_exports = []
    failed_exports = []

    for format_name, display_name in export_formats:
        try:
            print(f"Exporting to {display_name}...")
            model.export(format=format_name, imgsz=224)
            successful_exports.append(display_name)
            print(f"{display_name} model exported successfully")
        except Exception as e:
            failed_exports.append((display_name, str(e)))
            print(f"{display_name} export failed: {e}")

    print(f"\nExport Summary:")
    print(f"Successful exports: {len(successful_exports)}")
    for export in successful_exports:
        print(f"   - {export}")

    if failed_exports:
        print(f"Failed exports: {len(failed_exports)}")
        for export, error in failed_exports:
            print(f"   - {export}: {error}")

def create_production_inference():
    """Create optimized inference function for production"""

    def predict_malaria(image_path, threshold=0.5):
        """
        Predict malaria from cell image

        Args:
            image_path: Path to the cell image
            threshold: Confidence threshold for prediction

        Returns:
            dict: Prediction results
        """
        try:
            results = model(image_path, verbose=False)

            predicted_class = results[0].names[results[0].probs.top1]
            confidence = results[0].probs.top1conf.item()
            probs = results[0].probs.data.cpu().numpy()
            class_names = list(results[0].names.values())

            is_reliable = confidence >= threshold

            if predicted_class == 'Parasitized':
                if confidence > 0.95:
                    recommendation = 'High confidence malaria detection. Immediate medical attention recommended.'
                    risk_level = 'high'
                elif confidence > 0.8:
                    recommendation = 'Possible malaria infection detected. Consult healthcare provider.'
                    risk_level = 'medium'
                else:
                    recommendation = 'Low confidence detection. Manual examination recommended.'
                    risk_level = 'low'
            else:
                if confidence > 0.95:
                    recommendation = 'No malaria parasites detected with high confidence.'
                    risk_level = 'low'
                elif confidence > 0.8:
                    recommendation = 'Likely no malaria infection. Monitor symptoms.'
                    risk_level = 'low'
                else:
                    recommendation = 'Uncertain result. Consider retesting or manual examination.'
                    risk_level = 'medium'

            return {
                'prediction': predicted_class,
                'confidence': confidence,
                'all_probabilities': {class_names[i]: float(probs[i]) for i in range(len(class_names))},
                'is_reliable': is_reliable,
                'recommendation': recommendation,
                'risk_level': risk_level
            }

        except Exception as e:
            return {
                'error': str(e),
                'prediction': None,
                'confidence': 0.0,
                'is_reliable': False,
                'recommendation': 'Error in prediction. Please try again.',
                'risk_level': 'error'
            }

    return predict_malaria

def create_model_report(accuracy, precision, recall, f1):
    """Create a comprehensive model performance report"""
    print("\n" + "="*60)
    print("MALARIA DETECTION MODEL - COMPREHENSIVE REPORT")
    print("="*60)

    print(f"\nPERFORMANCE METRICS:")
    print(f"   Test Accuracy:     {accuracy:.4f} ({accuracy*100:.2f}%)")
    print(f"   Precision:         {precision:.4f} ({precision*100:.2f}%)")
    print(f"   Recall:            {recall:.4f} ({recall*100:.2f}%)")
    print(f"   F1-Score:          {f1:.4f} ({f1*100:.2f}%)")

    print(f"\nCLINICAL INTERPRETATION:")
    print(f"   Sensitivity:       {recall:.4f} (Detects {recall*100:.1f}% of infected cases)")
    print(f"   Specificity:       {1-precision:.4f} (Correctly identifies {(1-precision)*100:.1f}% of uninfected)")
    print(f"   PPV (Precision):   {precision:.4f} ({precision*100:.1f}% of positive predictions are correct)")

    print(f"\nMEDICAL READINESS:")
    if accuracy > 0.95 and recall > 0.94:
        print("EXCELLENT - Ready for clinical assistance")
    elif accuracy > 0.90 and recall > 0.90:
        print("GOOD - Suitable for screening with oversight")
    else:
        print("NEEDS IMPROVEMENT - Not ready for clinical use")

    print(f"\nDEPLOYMENT RECOMMENDATIONS:")
    print("   - Use as screening tool with medical oversight")
    print("   - Implement confidence thresholds for uncertain cases")
    print("   - Provide clear medical disclaimers")
    print("   - Enable human-in-the-loop for low confidence predictions")

    print("\n" + "="*60)
if __name__ == "__main__":
    print("🔬 Starting Post-Training Evaluation...")

    test_results = evaluate_test_set()
    cm, accuracy, precision, recall, f1 = create_confusion_matrix()
    plot_training_progress()
    test_sample_predictions()

    export_model()

    predict_malaria = create_production_inference()

    create_model_report(accuracy, precision, recall, f1)
    print(f"Model saved at: {model_path}")
